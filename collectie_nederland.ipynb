# %%
import requests
import json
import csv
import pandas as pd

# %%
import time

# %%
query_terms = pd.read_csv("/Users/anesterov/reps/OutdatedObjectDescriptions/query_terms.csv")

# %%
query_list = query_terms['query'].to_list()

# %%
query_terms_list = [t for t in query_list if type(t) != float] # nan is float

# %%
len(query_terms_list)
# Out:
# 40

# %%
query_terms_list[0]
# Out:
# 'sodomi*'

# %%
def get_hits_per_term(term:str) -> tuple:
    '''
    Getting N hits per query terms returned in the collectienederland API search
    term: str;
    Returns dict {str:int/str} str in case of a request error
    '''

    # API query params
    url = "https://data.collectienederland.nl/api/search/v2/"
    params = {"q":term,
              "format":"json"}
    headers = {}

    # sending a request / getting json
    r = requests.get(url,params=params,headers=headers)
    
    if r.ok:
            
        hits = r.json()
        n = hits['result']['query']['numfound']
        
    else:
        n = "error"

    return (term,n)

# %%
hits_dict = {}
for term in query_terms_list:
    t_n = get_hits_per_term(term)
    time.sleep(3)
    hits_dict[term] = t_n[1]

# %%
hits_dict
# Out:
# {'sodomi*': 28,
#  'urani*': 795,
#  'onani*': 4,
#  'tegennatuurlijk': 0,
#  'travesti*': 225,
#  '248 bis': 9,
#  'COC': 151,
#  'homofi*': 35,
#  'lesbi*': 66,
#  'flikker': 7,
#  'potten OR poten': 13675,
#  'AIDS': 202,
#  'eonis*': 0,
#  '"seksuele inversie"': 0,
#  'homoseksu*': 177,
#  'geïnverteerd*': 1,
#  'faggot*': 38,
#  '"sea queens" OR "sea queen" ': 0,
#  'tribad*': 7,
#  'fricatrice*': 0,
#  'pederas*': 0,
#  'MtF*': 65,
#  'FtM*': 67,
#  'banjee*': 0,
#  'dandy*': 93,
#  'clones': 0,
#  'GRID': 121,
#  'hermafrodi*': 24,
#  'vermomming': 38,
#  'fairy OR fairies': 188,
#  'gay': 424,
#  'homo': 945,
#  'queer': 17,
#  'trans': 322,
#  'transgenderisme': 0,
#  'transseksualisme': 0,
#  '"intersekse variaties"': 0,
#  'genderdysforie': 0,
#  'genderidentiteitsstoornis': 0,
#  'stoornissen AND seksuele AND ontwikkeling': 0}

# %%
# export hits csv
# name of csv file

with open("/Users/anesterov/reps/OutdatedObjectDescriptions/query_hits.csv", 'w') as csvfile:

    csvwriter = csv.writer(csvfile)

    header =["term","n_hits"]
    csvwriter.writerow(header)

    rows = [[t,h] for t,h in hits_dict.items()]
    csvwriter.writerows(rows)

# %%
def get_objects(term:str) -> dict:
    '''
    Retrieving object's info containing a query term:

    {term:[{"aggregatedCHO":"URL","found_in":field}]}
    '''

    objects_info = []

    # request
    url = "https://data.collectienederland.nl/api/search/v2/"
    params = {"q":term,
              "page":"1", # !NB check if str or int
              "format":"json"}
    headers = {}

    r = requests.get(url,params=params,headers=headers)

    # _parse_objects(hits)
    # check output (if r is ok)
    # return 
    # objects_info.extend(return)
    
    # pagination
    last_page = hits['resul']['pagination']['lastPage']

    for p in range(2,last_page+1):
        params['page'] = p
        r = requests.get(url,params=params,headers=headers)
        # _parse_objects(hits)
        # objects_info.extend(return)

# %%
# the function below might not be necessary

# %%
def _parse_object(request_return, term:str) -> list:
    '''
    Parsing object's info from the request results
    A subfunction of get_objects
    Returns a list of objects with info per page
    request_return
    '''

    list_per_page = []

    if request_return.ok:
        hits = r.json()
        # parsing

        for item in hits['result']['items']:
            
            dict_per_item = {}

            # getting object's link
            object_url = item['item']['fields']['edm_aggregatedCHO'][0]['raw']
            dict_per_item['edm_aggregatedCHO'] = object_url

            # check where the query term was found
             # fields, in which a query term will be searched (after the results are retrieved)
            search_fields = ['dc_coverage','dc_description','dc_subject','dc_title','skos_prefLabel']
            found_in = [] # storing the field names, in which the term was found
            
            for field in search_fields:
                # if field in item['item']['fields'].keys() ?
                for field_value in item['item']['fields'][field]:
                    if field_value['language'] == 'nl':
                        field_value['raw'] # search the term here
                        # if found:
                        # record the field name
                        # found_in.append(field)
                    else:
                        continue

            dict_per_item['found_in'] = found_in
            list_per_page.append(dict_per_item)
                
    return list_per_page

# %%
# searching over object terms
# &qf[]=dc_subject_facet:term

# %%
type(hits['result']['pagination']['lastPage'])
# Out:
# int

# %%
# 25 items per page
len(hits['result']['items'])
# Out:
# 25

# %%
r.ok
# Out:
# True

# %%
['dc_coverage','dc_description','dc_subject','dc_title','skos_prefLabel']

# %%
hits['result']['items'][0]['item'].keys()
# Out:
# dict_keys(['doc_id', 'doc_type', 'fields'])

# %%
hits['result']['items'][0]['item']['fields']['dc_coverage']
# Out:
# [{'language': 'nl',
#   '@type': 'Literal',
#   'value': 'tweede kwart 19e eeuw',
#   'raw': 'tweede kwart 19e eeuw'},
#  {'language': 'en',
#   '@type': 'Literal',
#   'value': 'second quarter 19th century',
#   'raw': 'second quarter 19th century'}]

# %%
for item in hits['result']['items']:
    print(item['item']['fields'])
    break
# Out:
# {'dc_coverage': [{'language': 'nl', '@type': 'Literal', 'value': 'derde kwart 18e eeuw', 'raw': 'derde kwart 18e eeuw'}, {'language': 'en', '@type': 'Literal', 'value': 'third quarter 18th century', 'raw': 'third quarter 18th century'}], 'dc_creator': [{'language': 'en', '@type': 'Literal', 'value': 'anonymous', 'raw': 'anonymous'}, {'language': 'nl', '@type': 'Literal', 'value': 'anoniem', 'raw': 'anoniem'}, {'language': 'nl', '@type': 'Literal', 'value': 'kopie naar\xa0', 'raw': 'kopie naar\xa0'}], 'dc_description': [{'language': 'nl', '@type': 'Literal', 'value': 'Portret van Anna van Hannover (1709-59), zuster van Frederick Louis, de Prins van Wales, en echtgenote van Prins Willem IV. Buste naar links, aanziend. Naar een origineel uit 1736 door Bernardus Accama (I) in Rijksmuseum Paleis Het Loo, Apeldoorn. Vroeger geïnterpreteerd als een portret van Charles Edward Stuart (1720-88). Bonnie Prince Charlie in travestie in de japon van het dienstmeisje Betty Burke bij zijn vlucht van Benbecula (Hebriden) naar Skye in 1746. Onderdeel van de collectie portretminiaturen.', 'raw': 'Portret van Anna van Hannover (1709-59), zuster van Frederick Louis, de Prins van Wales, en echtgenote van Prins Willem IV. Buste naar links, aanziend. Naar een origineel uit 1736 door Bernardus Accama (I) in Rijksmuseum Paleis Het Loo, Apeldoorn. Vroeger '}], 'dc_identifier': [{'raw': 'SK-A-4398', '@type': 'Literal', 'value': 'SK-A-4398'}, {'raw': 'http://hdl.handle.net/10934/RM0001.COLLECT.10297', '@type': 'Literal', 'value': 'http://hdl.handle.net/10934/RM0001.COLLECT.10297'}], 'dc_publisher': [{'raw': 'Rijksmuseum', '@type': 'Literal', 'value': 'Rijksmuseum'}], 'dc_rights': [{'language': 'en', '@type': 'Literal', 'value': 'Public Domain', 'raw': 'Public Domain'}, {'language': 'nl', '@type': 'Literal', 'value': 'Publiek Domein', 'raw': 'Publiek Domein'}], 'dc_subject': [{'language': 'nl', '@type': 'Literal', 'value': 'Anna van Hannover', 'raw': 'Anna van Hannover'}], 'dc_title': [{'language': 'nl', '@type': 'Literal', 'value': 'Anna van Hannover (1709-59). Zuster van Frederick Louis, Prins van Wales, en echtgenote van Prins Willem IV.', 'raw': 'Anna van Hannover (1709-59). Zuster van Frederick Louis, Prins van Wales, en echtgenote van Prins Willem IV.'}], 'dc_type': [{'language': 'nl', '@type': 'Literal', 'value': 'miniatuur (schildering)', 'raw': 'miniatuur (schildering)'}, {'language': 'en', '@type': 'Literal', 'value': 'miniature (painting)', 'raw': 'miniature (painting)'}], 'dcterms_created': [{'language': 'en', '@type': 'Literal', 'value': '1735 - 1745', 'raw': '1735 - 1745'}, {'language': 'nl', '@type': 'Literal', 'value': '1735 - 1745', 'raw': '1735 - 1745'}], 'dcterms_extent': [{'language': 'en', '@type': 'Literal', 'value': 'drager\xa0width\xa07\xa0cm', 'raw': 'drager\xa0width\xa07\xa0cm'}, {'language': 'nl', '@type': 'Literal', 'value': 'breedte\xa07\xa0cm', 'raw': 'breedte\xa07\xa0cm'}, {'language': 'en', '@type': 'Literal', 'value': 'drager\xa0height\xa08.8\xa0cm', 'raw': 'drager\xa0height\xa08.8\xa0cm'}, {'language': 'nl', '@type': 'Literal', 'value': 'breedte\xa08\xa0cm', 'raw': 'breedte\xa08\xa0cm'}, {'language': 'en', '@type': 'Literal', 'value': 'buitenmaat\xa0height\xa010.3\xa0cm', 'raw': 'buitenmaat\xa0height\xa010.3\xa0cm'}, {'language': 'en', '@type': 'Literal', 'value': 'buitenmaat\xa0depth\xa00.5\xa0cm', 'raw': 'buitenmaat\xa0depth\xa00.5\xa0cm'}, {'language': 'nl', '@type': 'Literal', 'value': 'hoogte\xa08,8\xa0cm', 'raw': 'hoogte\xa08,8\xa0cm'}, {'language': 'en', '@type': 'Literal', 'value': 'buitenmaat\xa0width\xa08\xa0cm', 'raw': 'buitenmaat\xa0width\xa08\xa0cm'}, {'language': 'nl', '@type': 'Literal', 'value': 'diepte\xa00,5\xa0cm', 'raw': 'diepte\xa00,5\xa0cm'}, {'language': 'nl', '@type': 'Literal', 'value': 'hoogte\xa010,3\xa0cm', 'raw': 'hoogte\xa010,3\xa0cm'}], 'dcterms_isPartOf': [{'language': 'nl', '@type': 'Literal', 'value': 'collectie: miniaturen', 'raw': 'collectie: miniaturen'}], 'dcterms_medium': [{'language' ...

# %% [markdown]
# ### a single record metadata (json-ld)

# %%
with open("/Users/anesterov/Downloads/M013571.json-ld.json",'r') as jf:
    record = json.load(jf)

# %%
record
# Out:
# [{'@id': 'http://data.collectienederland.nl/resource/document/joods-historisch/M013571',
#   '@type': ['http://www.europeana.eu/schemas/edm/ProvidedCHO'],
#   'http://purl.org/dc/elements/1.1/coverage': [{'@value': 'Nederland'}],
#   'http://purl.org/dc/elements/1.1/creator': [{'@value': 'Wesly, Jenny E. (1948-2016)'}],
#   'http://purl.org/dc/elements/1.1/description': [{'@value': 'Een groep demonstrerende mannen en vrouwen op een zomerse dag. Ze dragen spandoeken met zich mee.'}],
#   'http://purl.org/dc/elements/1.1/identifier': [{'@value': 'M013571'}],
#   'http://purl.org/dc/elements/1.1/source': [{'@value': 'Joods Museum'}],
#   'http://purl.org/dc/elements/1.1/subject': [{'@value': 'Utrecht (stad)'},
#    {'@value': 'demonstratie'},
#    {'@value': 'homoseksualiteit'},
#    {'@value': 'belangenorganisatie'},
#    {'@value': 'Wesly, Jenny E. (1948-2016)'},
#    {'@value': 'Sjalhomo'},
#    {'@value': 'spandoek'},
#    {'@value': 'portret'}],
#   'http://purl.org/dc/elements/1.1/title': [{'@value': 'Sjalhomo op Roze Zaterdag, de nationale homodag, 28 juni 1986'}],
#   'http://purl.org/dc/elements/1.1/type': [{'@value': 'foto'}],
#   'http://purl.org/dc/terms/alternative': [{'@value': 'M013571, foto, Jenny E. Wesly, 1986-06-28'}],
#   'http://purl.org/dc/terms/created': [{'@value': '1986-06-28'}],
#   'http://purl.org/dc/terms/extent': [{'@value': 'hoogte 27.9 cm'},
#    {'@value': 'breedte 35.3 cm'}],
#   'http://purl.org/dc/terms/medium': [{'@value': 'barietpapier'},
#    {'@value': 'papier'}],
#   'http://www.europeana.eu/schemas/edm/type': [{'@value': 'IMAGE'}]},
#  {'@id': 'http://data.collectienederland.nl/resource/aggregation/joods-historisch/M013571',
#   '@type': ['http://www.openarchives.org/ore/terms/Aggregation'],
#   'http://purl.org/dc/elements/1.1/rights': [{'@value': '© Joods Historisch Museum, Amsterdam'}],
#   'http://www.europeana.eu/schemas/edm/aggregatedCHO': [{'@id': 'http://data.collectienederland.nl/resource/document/joods-historisch/M013571'}],
#   'http://www.europeana.eu/schemas/edm/dataProvider': [{'@value': 'Joods Historisch Museum'}],
#   'http://www.europeana.eu/schemas/edm/isShownAt': [{'@id': 'http://data.jck.nl/resource/aggregation/jhm-museum/M013571'}],
#   'http://www.europeana.eu/schemas/edm/isShownBy': [{'@value': 'https://media.delving.org/thumbnail/jck/joods-historisch/d729/729NM013571/1000'}],
#   'http://www.europeana.eu/schemas/edm/object': [{'@value': 'https://media.delving.org/thumbnail/jck/joods-historisch/d729/729NM013571/1000'}],
#   'http://www.europeana.eu/schemas/edm/provider': [{'@value': 'Rijksdienst voor het Cultureel Erfgoed'}],
#   'http://www.europeana.eu/schemas/edm/rights': [{'@id': 'http://rightsstatements.org/vocab/InC/1.0/'}],
#   'http://www.openarchives.org/ore/terms/aggregates': [{'@id': '_:b2'},
#    {'@id': '_:b0'},
#    {'@id': '_:b1'}]},
#  {'@id': '_:b2',
#   '@type': ['http://schemas.delving.eu/nave/terms/DcnResource'],
#   'http://schemas.delving.eu/nave/terms/material': [{'@value': 'papier'},
#    {'@value': 'barietpapier'}],
#   'http://schemas.delving.eu/nave/terms/province': [{'@value': 'Noord-Holland'}],
#   'http://schemas.delving.eu/nave/terms/technique': [{'@value': 'gefotografeerd'}]},
#  {'@id': '_:b1',
#   '@type': ['http://schemas.delving.eu/nave/terms/DelvingResource'],
#   'http://schemas.delving.eu/nave/terms/allowDeepZoom': [{'@value': 'true'}],
#   'http://schemas.delving.eu/nave/terms/allowLinkedOpenData': [{'@value': 'true'}],
#   'http://schemas.delving.eu/nave/terms/allowSourceDownload': [{'@value': 'false'}],
#   'http://schemas.delving.eu/nave/terms/featured': [{'@value': 'false'}],
#   'http://schemas.delving.eu/nave/terms/public': [{'@value': 'true'}]},
#  {'@id': '_:b0',
#   '@type': ['http://schemas.delving.eu/nave/terms/RijksCollection'],
#   'http://schemas.delving.eu/nave/terms/rijksCollection': [{'@value': 'true'}]}]

# %% [markdown]
# ### Parsing institutions and N objects listed on CN

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException,WebDriverException,TimeoutException
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import re
import requests
import json

# %%
import pandas as pd

# %%
cn_providers = pd.DataFrame(columns=["institution","n_objects"])

# %%
cn_providers
# Out:
# Empty DataFrame
# Columns: [institution, n_objects]
# Index: []

# %%
path_to_driver = "/Users/anesterov/Downloads/chromedriver-mac-x64/chromedriver"

# %%
browser = webdriver.Chrome(executable_path=path_to_driver)
# Out:
# <ipython-input-11-68b6b2d671ac>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path=path_to_driver)

# %%
browser.get("https://data.collectienederland.nl/search/?")

# %%
soup = BeautifulSoup(browser.page_source, 'html.parser')

# %%
for li in soup.find("li", {"id": "edm_dataProvider"}).find("ul").find_all("li"):

    provider = [li["data-value"],int(li["data-count"])]
    cn_providers.loc[len(cn_providers)] = provider
# Out:
# <li data-count="747" data-value="Airborne Museum 'Hartenstein'" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AAirborne Museum 'Hartenstein'" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Airborne Museum 'Hartenstein' (747)
#                                     </a>
# </li> Airborne Museum 'Hartenstein' 747
# <li data-count="198938" data-value="Allard Pierson" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AAllard Pierson" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Allard Pierson (198938)
#                                     </a>
# </li> Allard Pierson 198938
# <li data-count="107901" data-value="Amsterdam Museum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AAmsterdam Museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Amsterdam Museum (107901)
#                                     </a>
# </li> Amsterdam Museum 107901
# <li data-count="526" data-value="Anton Pieck Museum Hattem" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AAnton Pieck Museum Hattem" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Anton Pieck Museum Hattem (526)
#                                     </a>
# </li> Anton Pieck Museum Hattem 526
# <li data-count="39259" data-value="Archief Eemland" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AArchief Eemland" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Archief Eemland (39259)
#                                     </a>
# </li> Archief Eemland 39259
# <li data-count="9757" data-value="Atlas of Mutual Heritage" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AAtlas of Mutual Heritage" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Atlas of Mutual Heritage (9757)
#                                     </a>
# </li> Atlas of Mutual Heritage 9757
# <li data-count="162350" data-value="Batavialand" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ABatavialand" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Batavialand (162350)
#                                     </a>
# </li> Batavialand 162350
# <li data-count="38" data-value="Beeldarchief Provincie Zuid-Holland" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ABeeldarchief Provincie Zuid-Holland" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Beeldarchief Provincie Zuid-Holland (38)
#                                     </a>
# </li> Beeldarchief Provincie Zuid-Holland 38
# <li data-count="51805" data-value="Beeldbank van de Rijksdienst voor het Cultureel Erfgoed" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ABeeldbank van de Rijksdienst voor het Cultureel Erfgoed" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Beeldbank van de Rijksdienst voor het Cultureel Erfgoed (51805)
#                                     </a>
# </li> Beeldbank van de Rijksdienst voor het Cultureel Erfgoed 51805
# <li data-count="17045" data-value="Belasting en Douane Museum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ABelasting en Douane Museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Belasting en Douane Museum (17045)
#                                     </a>
# </li> Belasting en Douane Museum 17045
# <li data-count="534" data-value="Bevrijdingsmuseum Zeeland" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ABevrijdingsmuseum Zeeland" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Bevrijdingsmuseum Zeeland (534)
#                                     </a>
# </li> Bevrijdingsmuseum Zeeland 534
# <li data-count="137" data-value="Brouws Museum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ABrouws Museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Brouws Museum (137)
#                                     </a>
# </li> Brouws Museum 137
# <li data-count="477" data-value="Buitenmuseum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ABuitenmuseum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Buitenmuseum (477)
#                                     </a>
# </li> Buitenmuseum 477
# <li data-count="32600" data-value="Centraal Museum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ACentraal Museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Centraal Museum (32600)
#                                     </a>
# </li> Centraal Museum 32600
# <li data-count="149484" data-value="Centre Ceramique" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ACentre Ceramique" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Centre Ceramique (149484)
#                                     </a>
# </li> Centre Ceramique 149484
# <li data-count="116630" data-value="Club van Suikerzakjesverzamelaars in Nederland" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AClub van Suikerzakjesverzamelaars in Nederland" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Club van Suikerzakjesverzamelaars in Nederland (116630)
#                                     </a>
# </li> Club van Suikerzakjesverzamelaars in Nederland 116630
# <li data-count="35334" data-value="CODA" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ACODA" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         CODA (35334)
#                                     </a>
# </li> CODA 35334
# <li data-count="57" data-value="Collectie Grote Kerk Naarden" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ACollectie Grote Kerk Naarden" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Collectie Grote Kerk Naarden (57)
#                                     </a>
# </li> Collectie Grote Kerk Naarden 57
# <li data-count="71" data-value="Collectie Hilversum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ACollectie Hilversum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Collectie Hilversum (71)
#                                     </a>
# </li> Collectie Hilversum 71
# <li data-count="578" data-value="Collectie van der Kop" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ACollectie van der Kop" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Collectie van der Kop (578)
#                                     </a>
# </li> Collectie van der Kop 578
# <li data-count="25" data-value="Comenius Museum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AComenius Museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Comenius Museum (25)
#                                     </a>
# </li> Comenius Museum 25
# <li data-count="22" data-value="Cultuurhistorische Vereniging Zevenaar" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ACultuurhistorische Vereniging Zevenaar" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         
museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Kröller-Müller Museum (22211)
#                                     </a>
# </li> Kröller-Müller Museum 22211
# <li data-count="2194" data-value="Kunstcollectie Provincie Gelderland" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AKunstcollectie Provincie Gelderland" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Kunstcollectie Provincie Gelderland (2194)
#                                     </a>
# </li> Kunstcollectie Provincie Gelderland 2194
# <li data-count="6374" data-value="Liemers Museum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ALiemers Museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Liemers Museum (6374)
#                                     </a>
# </li> Liemers Museum 6374
# <li data-count="3747" data-value="Literatuurmuseum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ALiteratuurmuseum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Literatuurmuseum (3747)
#                                     </a>
# </li> Literatuurmuseum 3747
# <li data-count="140" data-value="Marie Tak van Poortvliet Museum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMarie Tak van Poortvliet Museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Marie Tak van Poortvliet Museum (140)
#                                     </a>
# </li> Marie Tak van Poortvliet Museum 140
# <li data-count="858" data-value="Mauritshuis" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMauritshuis" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Mauritshuis (858)
#                                     </a>
# </li> Mauritshuis 858
# <li data-count="12191" data-value="Moluks Historisch Museum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMoluks Historisch Museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Moluks Historisch Museum (12191)
#                                     </a>
# </li> Moluks Historisch Museum 12191
# <li data-count="95358" data-value="Museon-Omniversum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseon-Omniversum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museon-Omniversum (95358)
#                                     </a>
# </li> Museon-Omniversum 95358
# <li data-count="599" data-value="Museum 't Behouden Huys Terschelling" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum 't Behouden Huys Terschelling" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum 't Behouden Huys Terschelling (599)
#                                     </a>
# </li> Museum 't Behouden Huys Terschelling 599
# <li data-count="5542" data-value="Museum Arnhem" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Arnhem" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Arnhem (5542)
#                                     </a>
# </li> Museum Arnhem 5542
# <li data-count="4017" data-value="Museum Beelden aan Zee" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Beelden aan Zee" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Beelden aan Zee (4017)
#                                     </a>
# </li> Museum Beelden aan Zee 4017
# <li data-count="1508" data-value="Museum Belvédère" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Belvédère" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Belvédère (1508)
#                                     </a>
# </li> Museum Belvédère 1508
# <li data-count="27705" data-value="Museum Bronbeek" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Bronbeek" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Bronbeek (27705)
#                                     </a>
# </li> Museum Bronbeek 27705
# <li data-count="243" data-value="Museum Bussemakerhuis" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Bussemakerhuis" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Bussemakerhuis (243)
#                                     </a>
# </li> Museum Bussemakerhuis 243
# <li data-count="74709" data-value="Museum Catharijneconvent" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Catharijneconvent" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Catharijneconvent (74709)
#                                     </a>
# </li> Museum Catharijneconvent 74709
# <li data-count="1725" data-value="Museum de Fundatie" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum de Fundatie" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum de Fundatie (1725)
#                                     </a>
# </li> Museum de Fundatie 1725
# <li data-count="2576" data-value="Museum Dr8888" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Dr8888" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Dr8888 (2576)
#                                     </a>
# </li> Museum Dr8888 2576
# <li data-count="343" data-value="Museum Elburg" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Elburg" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Elburg (343)
#                                     </a>
# </li> Museum Elburg 343
# <li data-count="26159" data-value="Museum Flehite" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Flehite" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Flehite (26159)
#                                     </a>
# </li> Museum Flehite 26159
# <li data-count="250" data-value="Museum Heerenveen" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Heerenveen" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Heerenveen (250)
#                                     </a>
# </li> Museum Heerenveen 250
# <li data-count="1718" data-value="Museum Henriette Polak" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Henriette Polak" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum
rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Tweestromenland (31)
#                                     </a>
# </li> Museum Tweestromenland 31
# <li data-count="2654" data-value="Museum Veere" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Veere" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Veere (2654)
#                                     </a>
# </li> Museum Veere 2654
# <li data-count="5555" data-value="Museum Vliegbasis Deelen" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Vliegbasis Deelen" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Vliegbasis Deelen (5555)
#                                     </a>
# </li> Museum Vliegbasis Deelen 5555
# <li data-count="117" data-value="Museum Weesp" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseum Weesp" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museum Weesp (117)
#                                     </a>
# </li> Museum Weesp 117
# <li data-count="17" data-value="Museumboerderij De Leimskoel" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseumboerderij De Leimskoel" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museumboerderij De Leimskoel (17)
#                                     </a>
# </li> Museumboerderij De Leimskoel 17
# <li data-count="177" data-value="Museumhaven Zeeland" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseumhaven Zeeland" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museumhaven Zeeland (177)
#                                     </a>
# </li> Museumhaven Zeeland 177
# <li data-count="45" data-value="Museumpark Orientalis" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuseumpark Orientalis" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Museumpark Orientalis (45)
#                                     </a>
# </li> Museumpark Orientalis 45
# <li data-count="1045" data-value="Muzeeaquarium Delfzijl" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AMuzeeaquarium Delfzijl" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Muzeeaquarium Delfzijl (1045)
#                                     </a>
# </li> Muzeeaquarium Delfzijl 1045
# <li data-count="435546" data-value="Nationaal Archief" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ANationaal Archief" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Nationaal Archief (435546)
# ...
# <i class="fa fa-fw fa-square-o"></i>
#                                         Rijksmuseum de Gevangenpoort (587)
#                                     </a>
# </li> Rijksmuseum de Gevangenpoort 587
# <li data-count="1498" data-value="Rijksmuseum Muiderslot" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ARijksmuseum Muiderslot" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Rijksmuseum Muiderslot (1498)
#                                     </a>
# </li> Rijksmuseum Muiderslot 1498
# <li data-count="8456" data-value="Rijksmuseum Twenthe" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ARijksmuseum Twenthe" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Rijksmuseum Twenthe (8456)
#                                     </a>
# </li> Rijksmuseum Twenthe 8456
# <li data-count="151158" data-value="Rijksmuseum van Oudheden" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ARijksmuseum van Oudheden" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Rijksmuseum van Oudheden (151158)
#                                     </a>
# </li> Rijksmuseum van Oudheden 151158
# <li data-count="267796" data-value="RKD – Nederlands Instituut voor Kunstgeschiedenis." role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ARKD – Nederlands Instituut voor Kunstgeschiedenis." rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         RKD – Nederlands Instituut voor Kunstgeschiedenis. (267796)
#                                     </a>
# </li> RKD – Nederlands Instituut voor Kunstgeschiedenis. 267796
# <li data-count="826" data-value="RoMeO Rotterdams Openbaar Vervoer Museum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ARoMeO Rotterdams Openbaar Vervoer Museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         RoMeO Rotterdams Openbaar Vervoer Museum (826)
#                                     </a>
# </li> RoMeO Rotterdams Openbaar Vervoer Museum 826
# <li data-count="327" data-value="Singer Laren" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ASinger Laren" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Singer Laren (327)
#                                     </a>
# </li> Singer Laren 327
# <li data-count="10635" data-value="Slot Loevestein" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ASlot Loevestein" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Slot Loevestein (10635)
#                                     </a>
# </li> Slot Loevestein 10635
# <li data-count="9176" data-value="Stadskasteel Zaltbommel" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStadskasteel Zaltbommel" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Stadskasteel Zaltbommel (9176)
#                                     </a>
# </li> Stadskasteel Zaltbommel 9176
# <li data-count="55" data-value="Stadsmuseum Doetinchem" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStadsmuseum Doetinchem" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Stadsmuseum Doetinchem (55)
#                                     </a>
# </li> Stadsmuseum Doetinchem 55
# <li data-count="2478" data-value="Stadsmuseum Harderwijk" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStadsmuseum Harderwijk" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Stadsmuseum Harderwijk (2478)
#                                     </a>
# </li> Stadsmuseum Harderwijk 2478
# <li data-count="3110" data-value="Stedelijk Museum Schiedam" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStedelijk Museum Schiedam" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Stedelijk Museum Schiedam (3110)
#                                     </a>
# </li> Stedelijk Museum Schiedam 3110
# <li data-count="22710" data-value="Stedelijk Museum Zutphen" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStedelijk Museum Zutphen" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Stedelijk Museum Zutphen (22710)
#                                     </a>
# </li> Stedelijk Museum Zutphen 22710
# <li data-count="723" data-value="Stichting Egress Foundation CSROT" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStichting Egress Foundation CSROT" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Stichting Egress Foundation CSROT (723)
#                                     </a>
# </li> Stichting Egress Foundation CSROT 723
# <li data-count="694" data-value="Stichting Erfgoed Meubelfabriek L.O.V." role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStichting Erfgoed Meubelfabriek L.O.V." rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Stichting Erfgoed Meubelfabriek L.O.V. (694)
#                                     </a>
# </li> Stichting Erfgoed Meubelfabriek L.O.V. 694
# <li data-count="70" data-value="Stichting Eusebius Arnhem" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStichting Eusebius Arnhem" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Stichting Eusebius Arnhem (70)
#                                     </a>
# </li> Stichting Eusebius Arnhem 70
# <li data-count="86" data-value="Stichting Historisch Verpleegkundig Bezit" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStichting Historisch Verpleegkundig Bezit" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Stichting Historisch Verpleegkundig Bezit (86)
#                                     </a>
# </li> Stichting Historisch Verpleegkundig Bezit 86
# <li data-count="1539" data-value="Stichting Kunst in de Publieke Ruimte in Arnhem" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStichting Kunst in de Publieke Ruimte in Arnhem" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Stichting Kunst in de Publieke Ruimte in Arnhem (1539)
#                                     </a>
# </li> Stichting Kunst in de Publieke Ruimte in Arnhem 1539
# <li data-count="328" data-value="Stichting Oude Groninger Kerken" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStichting Oude Groninger Kerken" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Stichting Oude Groninger Kerken (328)
#                                     </a>
# </li> Stichting Oude Groninger Kerken 328
# <li data-count="197" data-value="Streekarchivariaat Liemers en Doesburg" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStreekarchivariaat Liemers en Doesburg" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Streekarchivariaat Liemers en Doesburg (197)
#                                     </a>
# </li> Streekarchivariaat Liemers en Doesburg 197
# <li data-count="339" data-value="Streekmuseum de Roode Tooren" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStreekmuseum de Roode Tooren" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Streekmuseum de Roode Tooren (339)
#                                     </a>
# </li> Streekmuseum de Roode Tooren 339
# <li data-count="15641" data-value="Streekmuseum Jan Anderson" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStreekmuseum Jan Anderson" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Streekmuseum Jan Anderson (15641)
#                                     </a>
# </li> Streekmuseum Jan Anderson 15641
# <li data-count="23508" data-value="Streekmuseum Krimpenerwaard" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStreekmuseum Krimpenerwaard" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Streekmuseum Krimpenerwaard (23508)
#                                     </a>
# </li> Streekmuseum Krimpenerwaard 23508
# <li data-count="100" data-value="Streekmuseum Volkssterrenwacht Burgum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AStreekmuseum Volkssterrenwacht Burgum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Streekmuseum Volkssterrenwacht Burgum (100)
#                                     </a>
# </li> Streekmuseum Volkssterrenwacht Burgum 100
# <li data-count="16283" data-value="TextielMuseum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ATextielMuseum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         TextielMuseum (16283)
#                                     </a>
# </li> TextielMuseum 16283
# <li data-count="37380" data-value="Textile Research Centre" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ATextile Research Centre" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Textile Research Centre (37380)
#                                     </a>
# </li> Textile Research Centre 37380
# <li data-count="60430" data-value="Teylers Museum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ATeylers Museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Teylers Museum (60430)
#                                     </a>
# </li> Teylers Museum 60430
# <li data-count="207" data-value="TwentseWelle" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3ATwentseWelle" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         TwentseWelle (207)
#                                     </a>
# </li> TwentseWelle 207
# <li data-count="127" data-value="Universiteitsmuseum Groningen" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AUniversiteitsmuseum Groningen" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Universiteitsmuseum Groningen (127)
#                                     </a>
# </li> Universiteitsmuseum Groningen 127
# <li data-count="4405" data-value="Universiteitsmuseum Utrecht" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AUniversiteitsmuseum Utrecht" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Universiteitsmuseum Utrecht (4405)
#                                     </a>
# </li> Universiteitsmuseum Utrecht 4405
# <li data-count="3701" data-value="Valkhof Museum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AValkhof Museum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Valkhof Museum (3701)
#                                     </a>
# </li> Valkhof Museum 3701
# <li data-count="172" data-value="Van 't Lindenhoutmuseum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AVan 't Lindenhoutmuseum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Van 't Lindenhoutmuseum (172)
#                                     </a>
# </li> Van 't Lindenhoutmuseum 172
# <li data-count="3265" data-value="Van Abbemuseum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AVan Abbemuseum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Van Abbemuseum (3265)
#                                     </a>
# </li> Van Abbemuseum 3265
# <li data-count="6604" data-value="Verzamelingen van de gemeente Veere" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AVerzamelingen van de gemeente Veere" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Verzamelingen van de gemeente Veere (6604)
#                                     </a>
# </li> Verzamelingen van de gemeente Veere 6604
# <li data-count="89" data-value="Voerman Stadsmuseum Hattem" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AVoerman Stadsmuseum Hattem" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Voerman Stadsmuseum Hattem (89)
#                                     </a>
# </li> Voerman Stadsmuseum Hattem 89
# <li data-count="63476" data-value="Vrijheidsmuseum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AVrijheidsmuseum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Vrijheidsmuseum (63476)
#                                     </a>
# </li> Vrijheidsmuseum 63476
# <li data-count="93408" data-value="Wageningen UR" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AWageningen UR" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Wageningen UR (93408)
#                                     </a>
# </li> Wageningen UR 93408
# <li data-count="2274" data-value="Watersnoodmuseum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AWatersnoodmuseum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Watersnoodmuseum (2274)
#                                     </a>
# </li> Watersnoodmuseum 2274
# <li data-count="15061" data-value="Zeeuws maritiem muZEEum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AZeeuws maritiem muZEEum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Zeeuws maritiem muZEEum (15061)
#                                     </a>
# </li> Zeeuws maritiem muZEEum 15061
# <li data-count="21774" data-value="Zuiderzeemuseum" role="presentation">
# <a class="facet-link" href="?q=&amp;qf[]=edm_dataProvider%3AZuiderzeemuseum" rel="nofollow" role="menuitem" tabindex="-1">
# <i class="fa fa-fw fa-square-o"></i>
#                                         Zuiderzeemuseum (21774)
#                                     </a>
# </li> Zuiderzeemuseum 21774

# %%
cn_providers.to_csv("/Users/anesterov/cn_providers.csv")

# %%
browser.close()
