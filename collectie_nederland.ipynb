# %%
import requests
import json

# %%
url = "https://data.collectienederland.nl/api/search/v2/"
params = {"qf[]":"dc_subject_facet:travestie",
        "format":"json"}
headers = {}

# %%
# searching over object terms
# &qf[]=dc_subject_facet:term

# %%
r = requests.get(url,params=params,headers=headers)
hits = r.json()

# %%
hits['result'].keys()
# Out:
# dict_keys(['query', 'pagination', 'layout', 'items', 'facets'])

# %%
# 25 items per page
len(hits['result']['items'])
# Out:
# 25

# %%
hits['result']
# Out:
# {'query': {'numfound': 156,
#   'terms': '',
#   'breadCrumbs': [{'href': 'qf=dc_subject_facet%3Atravestie',
#     'display': 'dc_subject_facet:travestie',
#     'field': 'dc_subject_facet',
#     'localised_field': 'Onderwerp',
#     'value': 'travestie',
#     'is_last': True}]},
#  'pagination': {'start': 1,
#   'rows': 25,
#   'numFound': 156,
#   'hasNext': True,
#   'nextPage': 26,
#   'currentPage': 1,
#   'nextPageNumber': 2,
#   'hasPrevious': False,
#   'previousPage': 0,
#   'previousPageNumber': 0,
#   'firstPage': 1,
#   'lastPage': 7,
#   'links': [{'start': 1, 'isLinked': False, 'pageNumber': 1},
#    {'start': 26, 'isLinked': True, 'pageNumber': 2},
#    {'start': 51, 'isLinked': True, 'pageNumber': 3},
#    {'start': 76, 'isLinked': True, 'pageNumber': 4},
#    {'start': 101, 'isLinked': True, 'pageNumber': 5},
#    {'start': 126, 'isLinked': True, 'pageNumber': 6},
#    {'start': 151, 'isLinked': True, 'pageNumber': 7}]},
#  'layout': {'layout': [{'name': 'dcterms_provenance', 'i18n': 'Herkomst'},
#    {'name': 'dcterms_references', 'i18n': 'Verwijst naar'},
#    {'name': 'dcterms_created', 'i18n': 'Datering'},
#    {'name': 'dcterms_isPartOf', 'i18n': 'Is deel van'},
#    {'name': 'europeana_rights', 'i18n': 'Rechten'},
#    {'name': 'dc_contributor', 'i18n': 'Bijdrager'},
#    {'name': 'europeana_aggregatedCHO', 'i18n': 'edm_aggregatedCHO'},
#    {'name': 'dc_rights', 'i18n': 'Rechten'},
#    {'name': 'dcterms_isVersionOf', 'i18n': 'Is versie van'},
#    {'name': 'europeana_hasView', 'i18n': 'edm_hasView'},
#    {'name': 'dcterms_temporal', 'i18n': 'dcterms_temporal'},
#    {'name': 'dc_coverage', 'i18n': 'Vervaardigingsplaats / vindplaats'},
#    {'name': 'europeana_uri', 'i18n': 'edm_uri'},
#    {'name': 'europeana_language', 'i18n': 'Taal'},
#    {'name': 'dcterms_requires', 'i18n': 'Vereist'},
#    {'name': 'europeana_type', 'i18n': 'edm_type'},
#    {'name': 'dc_format', 'i18n': 'Formaat'},
#    {'name': 'dcterms_isRequiredBy', 'i18n': 'Is vereist door'},
#    {'name': 'europeana_currentLocation', 'i18n': 'Huidige locatie'},
#    {'name': 'europeana_begin', 'i18n': 'edm_begin'},
#    {'name': 'europeana_collectionName', 'i18n': 'Collectienaam'},
#    {'name': 'europeana_object', 'i18n': 'Object'},
#    {'name': 'dcterms_extent', 'i18n': 'Afmetingen'},
#    {'name': 'europeana_dataProvider', 'i18n': 'Dataprovider'},
#    {'name': 'dcterms_issued', 'i18n': 'Datum uitgave'},
#    {'name': 'europeana_hasMet', 'i18n': 'edm_hasMet'},
#    {'name': 'dcterms_replaces', 'i18n': 'Vervangt'},
#    {'name': 'europeana_collectionTitle', 'i18n': 'Collectietitel'},
#    {'name': 'dc_publisher', 'i18n': 'Uitgever'},
#    {'name': 'europeana_country', 'i18n': 'Land'},
#    {'name': 'dcterms_isFormatOf', 'i18n': 'Is formaat van'},
#    {'name': 'dcterms_tableOfContents', 'i18n': 'Inhoudsopgave'},
#    {'name': 'dcterms_isReplacedBy', 'i18n': 'Is vervangen door'},
#    {'name': 'europeana_isRepresentationOf', 'i18n': 'Is afbeelding van'},
#    {'name': 'dc_description', 'i18n': 'Beschrijving'},
#    {'name': 'dc_type', 'i18n': 'Soort object'},
#    {'name': 'dcterms_alternative', 'i18n': 'Alternatief'},
#    {'name': 'dc_title', 'i18n': 'Titel'},
#    {'name': 'dcterms_hasVersion', 'i18n': 'Heeft versie'},
#    {'name': 'dcterms_hasFormat', 'i18n': 'Heeft formaat'},
#    {'name': 'dc_source', 'i18n': 'Bron'},
#    {'name': 'europeana_provider', 'i18n': 'Provider'},
#    {'name': 'dcterms_spatial', 'i18n': 'Plaats van vervaardiging'},
#    {'name': 'dcterms_hasPart', 'i18n': 'Heeft onderdelen'},
#    {'name': 'dc_language', 'i18n': 'Taal'},
#    {'name': 'dc_Title', 'i18n': 'dc_Title'},
#    {'name': 'dc_date', 'i18n': 'Vervaardigingsdatum'},
#    {'name': 'dc_identifier', 'i18n': 'Identificatie'},
#    {'name': 'europeana_end', 'i18n': 'edm_end'},
#    {'name': 'dc_relation', 'i18n': 'Verwijzing(en)'},
#    {'name': 'dcterms_medium', 'i18n': 'Medium'},
#    {'name': 'dcterms_rightsHolder', 'i18n': 'Rechthebbende'},
#    {'name': 'europeana_isRelatedTo', 'i18n': 'Heeft relatie met'},
#    {'name': 'europeana_source', 'i18n': 'edm_source'},
#    {'name': 'europeana_unstored', 'i18n': 'edm_unstored'},
#    {'name': 'europeana_isShownAt', 'i18n': 'Originele context'},
#    {'name': 'dc_creator', 'i18n': 'Vervaardiger'},
#    {'name': 'dc_subject', 'i18n': 'Onderwerp'},
#    {'name': 'dcterms_isReferencedBy', 'i18n': 'Is verwezen door'},
#    {'name': 'europeana_isShownBy', 'i18n': 'edm_isShownBy'}]},
#  'items': [{'item': {'doc_id': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#     'doc_type': 'void_edmrecord',
#     'fields': {'dc_creator': [{'value': 'Cornelis Kruseman',
#        'raw': 'Cornelis Kruseman',
#        '@type': 'Literal'}],
#      'dc_subject': [{'value': 'Greek mythology',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'Greek mythology'},
#       {'value': 'woman', 'language': 'en', '@type': 'Literal', 'raw': 'woman'},
#       {'value': '66254', 'raw': '66254', '@type': 'Literal'},
#       {'value': 'Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity'},
#       {'value': 'Griekse mythologie',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'Griekse mythologie'},
#       {'value': '94C22', 'raw': '94C22', '@type': 'Literal'},
#       {'value': '63039', 'raw': '63039', '@type': 'Literal'},
#       {'value': 'travesty',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'travesty'},
#       {'value': '63173', 'raw': '63173', '@type': 'Literal'},
#       {'value': 'travestie',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'travestie'},
#       {'value': 'vrouw',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'vrouw'}],
#      'dc_title': [{'value': 'Achilles onder de maagden (te Rome, Galerie Faesch)',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'Achilles onder de maagden (te Rome, Galerie Faesch)'},
#       {'value': 'Achilles with the virgins',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'Achilles with the virgins'}],
#      'dc_type': [{'value': 'olieverfschets',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'olieverfschets'}],
#      'dcterms_created': [{'language': 'en', '@type': 'Literal'}],
#      'dcterms_medium': [{'value': 'olieverf',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'olieverf'}],
#      'dcterms_provenance': [{'value': 'Laatst bekende of huidige verblijfplaats: Cornelis François Roos (Amsterdam (city)) 1858-02-16 - 1858-02-18, nr. 13, p. 23',
#        'raw': 'Laatst bekende of huidige verblijfplaats: Cornelis François Roos (Amsterdam (city)) 1858-02-16 - 1858-02-18, nr. 13, p. 23',
#        '@type': 'Literal'}],
#      'delving_spec': {'value': 'rkd-images',
#       'raw': 'rkd-images',
#       '@type': 'Literal'},
#      'edm_aggregatedCHO': [{'value': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-266646',
#        'id': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-266646',
#        '@type': 'URIRef',
#        'raw': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-266646'}],
#      'edm_dataProvider': [{'value': 'RKD – Nederlands Instituut voor Kunstgeschiedenis.',
#        'raw': 'RKD – Nederlands Instituut voor Kunstgeschiedenis.',
#        '@type': 'Literal'}],
#      'edm_hasView': [{'value': '_:b1',
#        'id': '_:b1',
#        '@type': 'URIRef',
#        'raw': '_:b1'}],
#      'edm_isShownAt': [{'value': 'https://rkd.nl/explore/images/266646',
#        'id': 'https://rkd.nl/explore/images/266646',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/explore/images/266646'}],
#      'edm_isShownBy': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        'id': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083'}],
#      'edm_object': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        'id': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083'}],
#      'edm_provider': [{'value': 'Rijksdienst voor het Cultureel Erfgoed',
#        'raw': 'Rijksdienst voor het Cultureel Erfgoed',
#        '@type': 'Literal'}],
#      'edm_rights': [{'value': 'http://www.europeana.eu/rights/unknown/',
#        'raw': 'http://www.europeana.eu/rights/unknown/',
#        '@type': 'Literal'}],
#      'edm_type': [{'value': 'IMAGE', 'raw': 'IMAGE', '@type': 'Literal'}],
#      'entryURI': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-266646',
#      'foaf_name': [{'value': 'Cornelis Kruseman',
#        'raw': 'Cornelis Kruseman',
#        '@type': 'Literal'}],
#      'hubID': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#      'legacy': {'delving_collection': 'rkd-images',
#       'delving_orgId': 'dcn',
#       'delving_hasGeoHash': 'false',
#       'delving_hasDeepZoom': 'false',
#       'delving_recordType': 'mdr',
#       'delving_spec': 'rkd-images',
#       'delving_hubId': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#       'delving_hasLandingPage': 'true',
#       'delving_hasDigitalObject': 'true'},
#      'nave_allowDeepZoom': [{'value': 'true',
#        'raw': 'true',
#        '@type': 'Literal'}],
#      'nave_allowLinkedOpenData': [{'value': 'true',
#        'raw': 'true',
#        '@type': 'Literal'}],
#      'nave_allowSourceDownload': [{'value': 'false',
#        'raw': 'false',
#        '@type': 'Literal'}],
#      'nave_featured': [{'value': 'false', 'raw': 'false', '@type': 'Literal'}],
#      'nave_id': {'value': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#       'raw': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#       '@type': 'Literal'},
#      'nave_material': [{'language': 'nl', '@type': 'Literal'}],
#      'nave_province': [{'value': 'Zuid-Holland',
#        'raw': 'Zuid-Holland',
#        '@type': 'Literal'}],
#      'nave_public': [{'value': 'true', 'raw': 'true', '@type': 'Literal'}],
#      'nave_resourceSortOrder': [{'value': '1',
#        'raw': '1',
#        '@type': 'Literal'}],
#      'nave_thumbLarge': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        '@type': 'Literal'}],
#      'nave_thumbMedium': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        '@type': 'Literal'}],
#      'nave_thumbSmall': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        '@type': 'Literal'}],
#      'ore_aggregates': [{'value': 'b2',
#        'id': 'b2',
#        '@type': 'Bnode',
#        'raw': 'b2'},
#       {'value': 'b0', 'id': 'b0', '@type': 'Bnode', 'raw': 'b0'}],
#      'orgID': 'dcn',
#      'rdf_type': [{'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://www.europeana.eu/schemas/edm/Agent',
#        'id': 'http://www.europeana.eu/schemas/edm/Agent',
#        '@type': 'URIRef',
#        'raw': 'http://www.europeana.eu/schemas/edm/Agent'},
#       {'value': 'http://schemas.delving.eu/nave/terms/DelvingResource',
#        'id': 'http://schemas.delving.eu/nave/terms/DelvingResource',
#        '@type': 'URIRef',
#        'raw': 'http://schemas.delving.eu/nave/terms/DelvingResource'},
#       {'value': 'http://schemas.delving.eu/nave/terms/DcnResource',
#        'id': 'http://schemas.delving.eu/nave/terms/DcnResource',
#        '@type': 'URIRef',
#        'raw': 'http://schemas.delving.eu/nave/terms/DcnResource'},
#       {'value': 'http://www.europeana.eu/schemas/edm/ProvidedCHO',
#        'id': 'http://www.europeana.eu/schemas/edm/ProvidedCHO',
#        '@type': 'URIRef',
#        'raw': 'http://www.europeana.eu/schemas/edm/ProvidedCHO'},
#       {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://www.openarchives.org/ore/terms/Aggregation',
#        'id': 'http://www.openarchives.org/ore/terms/Aggregation',
#        '@type': 'URIRef',
#        'raw': 'http://www.openarchives.org/ore/terms/Aggregation'},
#       {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://www.europeana.eu/schemas/edm/WebResource',
#        'id': 'http://www.europeana.eu/schemas/edm/WebResource',
#        '@type': 'URIRef',
#        'raw': 'http://www.europeana.eu/schemas/edm/WebResource'}],
#      'revision': 123,
#      'skos_prefLabel': [{'value': 'Griekse mythologie',
#        'raw': 'Griekse mythologie',
#        '@type': 'Literal'},
#       {'value': 'travesty', 'raw': 'travesty', '@type': 'Literal'},
#       {'value': 'Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity',
#        'raw': 'Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity',
#        '@type': 'Literal'},
#       {'value': '63173', 'raw': '63173', '@type': 'Literal'},
#       {'value': 'Cornelis Kruseman',
#        'raw': 'Cornelis Kruseman',
#        '@type': 'Literal'},
#       {'value': '94C22', 'raw': '94C22', '@type': 'Literal'},
#       {'value': 'Greek mythology',
#        'raw': 'Greek mythology',
#        '@type': 'Literal'},
#       {'value': 'woman', 'raw': 'woman', '@type': 'Literal'},
#       {'value': '63039', 'raw': '63039', '@type': 'Literal'},
#       {'value': 'vrouw', 'raw': 'vrouw', '@type': 'Literal'},
#       {'value': '66254', 'raw': '66254', '@type': 'Literal'},
#       {'value': 'travestie', 'raw': 'travestie', '@type': 'Literal'}],
#      'spec': 'rkd-images',
#      'system': {'spec': 'rkd-images',
#       'graph_name': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-266646/graph',
#       'created_at': '2023-12-07T23:23:19+01:00',
#       'hasLandingPage': 'true',
#       'slug': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#       'hasDeepZoom': 'false',
#       'hasDigitalObject': 'true',
#       'source_graph': '[{"@id":"http://opendata.rkd.nl/opensearch/artists/eac-cpf?q=kunstenaarsnummer:46663","@type":["http://www.europeana.eu/schemas/edm/Agent"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"Cornelis Kruseman"}],"http://xmlns.com/foaf/0.1/name":[{"@value":"Cornelis Kruseman"}]},{"@id":"_:b2","@type":["http://schemas.delving.eu/nave/terms/DelvingResource"],"http://schemas.delving.eu/nave/terms/allowDeepZoom":[{"@value":"true"}],"http://schemas.delving.eu/nave/terms/allowLinkedOpenData":[{"@value":"true"}],"http://schemas.delving.eu/nave/terms/allowSourceDownload":[{"@value":"false"}],"http://schemas.delving.eu/nave/terms/featured":[{"@value":"false"}],"http://schemas.delving.eu/nave/terms/public":[{"@value":"true"}]},{"@id":"http://www.iconclass.org/rkd/94C22","@type":["http://www.w3.org/2004/02/skos/core#Concept"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity"},{"@value":"94C22"}]},{"@id":"_:b0","@type":["http://schemas.delving.eu/nave/terms/DcnResource"],"http://schemas.delving.eu/nave/terms/material":[{"@language":"nl"}],"http://schemas.delving.eu/nave/terms/province":[{"@value":"Zuid-Holland"}]},{"@id":"http://rkd.nl/explore/thesaurus?term=66254","@type":["http://www.w3.org/2004/02/skos/core#Concept"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"travestie"},{"@value":"66254"},{"@value":"travesty"}]},{"@id":"http://rkd.nl/explore/thesaurus?term=63173","@type":["http://www.w3.org/2004/02/skos/core#Concept"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"vrouw"},{"@value":"woman"},{"@value":"63173"}]},{"@id":"http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-266646","@type":["http://www.openarchives.org/ore/terms/Aggregation"],"http://www.europeana.eu/schemas/edm/aggregatedCHO":[{"@id":"http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-266646"}],"http://www.europeana.eu/schemas/edm/dataProvider":[{"@value":"RKD – Nederlands Instituut voor Kunstgeschiedenis."}],"http://www.europeana.eu/schemas/edm/hasView":[{"@id":"_:b1"}],"http://www.europeana.eu/schemas/edm/isShownAt":[{"@id":"https://rkd.nl/explore/images/266646"}],"http://www.europeana.eu/schemas/edm/isShownBy":[{"@id":"https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083"}],"http://www.europeana.eu/schemas/edm/object":[{"@id":"https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083"}],"http://www.europeana.eu/schemas/edm/provider":[{"@value":"Rijksdienst voor het Cultureel Erfgoed"}],"http://www.europeana.eu/schemas/edm/rights":[{"@value":"http://www.europeana.eu/rights/unknown/"}],"http://www.openarchives.org/ore/terms/aggregates":[{"@id":"_:b2"},{"@id":"_:b0"}]},{"@id":"http://rkd.nl/explore/thesaurus?term=63039","@type":["http://www.w3.org/2004/02/skos/core#Concept"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"Griekse mythologie"},{"@value":"Greek mythology"},{"@value":"63039"}]},{"@id":"http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-266646","@type":["http://www.europeana.eu/schemas/edm/ProvidedCHO"],"http://purl.org/dc/elements/1.1/creator":[{"@value":"Cornelis Kruseman"}],"http://purl.org/dc/elements/1.1/subject":[{"@value":"woman","@language":"en"},{"@value":"94C22"},{"@value":"Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity","@language":"en"},{"@value":"63173"},{"@value":"travestie","@language":"nl"},{"@value":"travesty","@language":"en"},{"@value":"66254"},{"@value":"Griekse mythologie","@language":"nl"},{"@value":"vrouw","@language":"nl"},{"@value":"Greek mythology","@language":"en"},{"@value":"63039"}],"http://purl.org/dc/elements/1.1/title":[{" ...
#       'about_uri': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-266646',
#       'source_uri': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-266646',
#       'thumbnail': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#       'preview': 'detail/foldout/void_edmrecord/dcn_rkd-images_https-rkd.nl-explore-images-266646',
#       'modified_at': '2023-12-07T23:23:19+01:00',
#       'hasGeoHash': 'false'}}}},
#   {'item': {'doc_id': 'dcn_rkd-images_https-rkd.nl-explore-images-50725',
#     'doc_type': 'void_edmrecord',
#     'fields': {'dc_creator': [{'value': 'Paulus Moreelse',
#        'raw': 'Paulus Moreelse',
#        '@type': 'Literal'}],
#      'dc_date': [{'value': 'c. 1625-1630',
#        'raw': 'c. 1625-1630',
#        '@type': 'Literal'}],
#      'dc_subject': [{'value': '96A18211',
#        'raw': '96A18211',
#        '@type': 'Literal'},
#       {'value': '62873', 'raw': '62873', '@type': 'Literal'},
#       {'value': 'sickle',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'sickle'},
#       {'value': 'basket with fruits',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'basket with fruits'},
#       {'value': '63655', 'raw': '63655', '@type': 'Literal'},
#       {'value': 'travestie',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'travestie'},
#       {'value': '67292', 'raw': '67292', '@type': 'Literal'},
#       {'value': 'mand met vruchten',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'mand met vruchten'},
#       {'value': 'travesty',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'travesty'},
#       {'value': 'jonge vrouw',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'jonge vrouw'},
#       {'value': 'Vertumnus, in the guise of an old woman, wooing Pomona',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'Vertumnus, in the guise of an old woman, wooing Pomona'},
#       {'value': '63041', 'raw': '63041', '@type': 'Literal'},
#       {'value': 'sikkel',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'sikkel'},
#       {'value': '66254', 'raw': '66254', '@type': 'Literal'},
#       {'value': 'druif', 'language': 'nl', '@type': 'Literal', 'raw': 'druif'},
#       {'value': '65455', 'raw': '65455', '@type': 'Literal'},
#       {'value': 'woods', 'language': 'en', '@type': 'Literal', 'raw': 'woods'},
#       {'value': 'Romeinse mythologie',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'Romeinse mythologie'},
#       {'value': '65463', 'raw': '65463', '@type': 'Literal'},
#       {'value': 'oude vrouw',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'oude vrouw'},
#       {'value': 'grape', 'language': 'en', '@type': 'Literal', 'raw': 'grape'},
#       {'value': 'Roman mythology',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'Roman mythology'},
#       {'value': 'young woman',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'young woman'},
#       {'value': 'bos', 'language': 'nl', '@type': 'Literal', 'raw': 'bos'},
#       {'value': 'old woman',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'old woman'},
#       {'value': '66060', 'raw': '66060', '@type': 'Literal'}],
#      'dc_title': [{'value': 'Vertumnus en Pomona (Ovidius, Metamorphoses XIV: 623)',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'Vertumnus en Pomona (Ovidius, Metamorphoses XIV: 623)'},
#       {'value': 'Vertumnus and Pomona (Ovid, Met. XIV: 623)',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'Vertumnus and Pomona (Ovid, Met. XIV: 623)'}],
#      'dc_type': [{'value': 'schilderij',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'schilderij'}],
#      'dcterms_created': [{'value': 'c. 1625-1630',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'c. 1625-1630'}],
#      'dcterms_medium': [{'value': 'olieverf',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'olieverf'}],
#      'dcterms_provenance': [{'value': 'Laatst bekende of huidige verblijfplaats: Rotterdam, Museum Boijmans Van Beuningen, inv./cat.nr. 1549',
#        'raw': 'Laatst bekende of huidige verblijfplaats: Rotterdam, Museum Boijmans Van Beuningen, inv./cat.nr. 1549',
#        '@type': 'Literal'}],
#      'delving_spec': {'value': 'rkd-images',
#       'raw': 'rkd-images',
#       '@type': 'Literal'},
#      'edm_aggregatedCHO': [{'value': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-50725',
#        'id': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-50725',
#        '@type': 'URIRef',
#        'raw': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-50725'}],
#      'edm_dataProvider': [{'value': 'RKD – Nederlands Instituut voor Kunstgeschiedenis.',
#        'raw': 'RKD – Nederlands Instituut voor Kunstgeschiedenis.',
#        '@type': 'Literal'}],
#      'edm_hasView': [{'value': '_:b1',
#        'id': '_:b1',
#        '@type': 'URIRef',
#        'raw': '_:b1'}],
#      'edm_isShownAt': [{'value': 'https://rkd.nl/explore/images/50725',
#        'id': 'https://rkd.nl/explore/images/50725',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/explore/images/50725'}],
#      'edm_isShownBy': [{'value': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc',
#        'id': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc'},
#       {'value': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200',
#        'id': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200'},
#       {'value': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87',
#        'id': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87'}],
#      'edm_object': [{'value': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87',
#        'id': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87'},
#       {'value': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc',
#        'id': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc'},
#       {'value': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200',
#        'id': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200'}],
#      'edm_provider': [{'value': 'Rijksdienst voor het Cultureel Erfgoed',
#        'raw': 'Rijksdienst voor het Cultureel Erfgoed',
#        '@type': 'Literal'}],
#      'edm_rights': [{'value': 'http://www.europeana.eu/rights/unknown/',
#        'raw': 'http://www.europeana.eu/rights/unknown/',
#        '@type': 'Literal'}],
#      'edm_type': [{'value': 'IMAGE', 'raw': 'IMAGE', '@type': 'Literal'}],
#      'entryURI': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-50725',
#      'foaf_name': [{'value': 'Paulus Moreelse',
#        'raw': 'Paulus Moreelse',
#        '@type': 'Literal'}],
#      'hubID': 'dcn_rkd-images_https-rkd.nl-explore-images-50725',
#      'legacy': {'delving_collection': 'rkd-images',
#       'delving_orgId': 'dcn',
#       'delving_hasGeoHash': 'false',
#       'delving_hasDeepZoom': 'false',
#       'delving_recordType': 'mdr',
#       'delving_spec': 'rkd-images',
#       'delving_hubId': 'dcn_rkd-images_https-rkd.nl-explore-images-50725',
#       'delving_hasLandingPage': 'true',
#       'delving_hasDigitalObject': 'true'},
#      'nave_allowDeepZoom': [{'value': 'true',
#        'raw': 'true',
#        '@type': 'Literal'}],
#      'nave_allowLinkedOpenData': [{'value': 'true',
#        'raw': 'true',
#        '@type': 'Literal'}],
#      'nave_allowSourceDownload': [{'value': 'false',
#        'raw': 'false',
#        '@type': 'Literal'}],
#      'nave_featured': [{'value': 'false', 'raw': 'false', '@type': 'Literal'}],
#      'nave_id': {'value': 'dcn_rkd-images_https-rkd.nl-explore-images-50725',
#       'raw': 'dcn_rkd-images_https-rkd.nl-explore-images-50725',
#       '@type': 'Literal'},
#      'nave_material': [{'language': 'nl', '@type': 'Literal'}],
#      'nave_province': [{'value': 'Zuid-Holland',
#        'raw': 'Zuid-Holland',
#        '@type': 'Literal'}],
#      'nave_public': [{'value': 'true', 'raw': 'true', '@type': 'Literal'}],
#      'nave_resourceSortOrder': [{'value': '1',
#        'raw': '1',
#        '@type': 'Literal'}],
#      'nave_thumbLarge': [{'value': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc',
#        'raw': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc',
#        '@type': 'Literal'},
#       {'value': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200',
#        'raw': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200',
#        '@type': 'Literal'},
#       {'value': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87',
#        'raw': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87',
#        '@type': 'Literal'}],
#      'nave_thumbMedium': [{'value': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200',
#        'raw': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200',
#        '@type': 'Literal'},
#       {'value': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc',
#        'raw': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc',
#        '@type': 'Literal'},
#       {'value': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87',
#        'raw': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87',
#        '@type': 'Literal'}],
#      'nave_thumbSmall': [{'value': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc',
#        'raw': 'https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc',
#        '@type': 'Literal'},
#       {'value': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87',
#        'raw': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87',
#        '@type': 'Literal'},
#       {'value': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200',
#        'raw': 'https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200',
#        '@type': 'Literal'}],
#      'ore_aggregates': [{'value': 'b2',
#        'id': 'b2',
#        '@type': 'Bnode',
#        'raw': 'b2'},
#       {'value': 'b0', 'id': 'b0', '@type': 'Bnode', 'raw': 'b0'}],
#      'orgID': 'dcn',
#      'rdf_type': [{'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://schemas.delving.eu/nave/terms/DelvingResource',
#        'id': 'http://schemas.delving.eu/nave/terms/DelvingResource',
#        '@type': 'URIRef',
#        'raw': 'http://schemas.delving.eu/nave/terms/DelvingResource'},
#       {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://www.europeana.eu/schemas/edm/Agent',
#        'id': 'http://www.europeana.eu/schemas/edm/Agent',
#        '@type': 'URIRef',
#        'raw': 'http://www.europeana.eu/schemas/edm/Agent'},
#       {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://schemas.delving.eu/nave/terms/DcnResource',
#        'id': 'http://schemas.delving.eu/nave/terms/DcnResource',
#        '@type': 'URIRef',
#        'raw': 'http://schemas.delving.eu/nave/terms/DcnResource'},
#       {'value': 'http://www.europeana.eu/schemas/edm/ProvidedCHO',
#        'id': 'http://www.europeana.eu/schemas/edm/ProvidedCHO',
#        '@type': 'URIRef',
#        'raw': 'http://www.europeana.eu/schemas/edm/ProvidedCHO'},
#       {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#        'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#        '@type': 'URIRef',
#        'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#       {'value': 'http://www.openarchives.org/ore/terms/Aggregation',
#        'id': 'http://www.openarchives.org/ore/terms/Aggregation',
#        '@type': 'URIRef',
#        'raw': 'http://www.openarchives.org/ore/terms/Aggregation'},
#       {'value': 'http://www.europeana.eu/schemas/edm/WebResource',
#        'id': 'http://www.europeana.eu/schemas/edm/WebResource',
#        '@type': 'URIRef',
#        'raw': 'http://www.europeana.eu/schemas/edm/WebResource'}],
#      'revision': 123,
#      'skos_prefLabel': [{'value': '65463', 'raw': '65463', '@type': 'Literal'},
#       {'value': '62873', 'raw': '62873', '@type': 'Literal'},
#       {'value': 'druif', 'raw': 'druif', '@type': 'Literal'},
#       {'value': 'oude vrouw', 'raw': 'oude vrouw', '@type': 'Literal'},
#       {'value': '66060', 'raw': '66060', '@type': 'Literal'},
#       {'value': '96A18211', 'raw': '96A18211', '@type': 'Literal'},
#       {'value': 'travesty', 'raw': 'travesty', '@type': 'Literal'},
#       {'value': 'Roman mythology',
#        'raw': 'Roman mythology',
#        '@type': 'Literal'},
#       {'value': '63041', 'raw': '63041', '@type': 'Literal'},
#       {'value': 'basket with fruits',
#        'raw': 'basket with fruits',
#        '@type': 'Literal'},
#       {'value': 'travestie', 'raw': 'travestie', '@type': 'Literal'},
#       {'value': 'grape', 'raw': 'grape', '@type': 'Literal'},
#       {'value': '63655', 'raw': '63655', '@type': 'Literal'},
#       {'value': 'jonge vrouw', 'raw': 'jonge vrouw', '@type': 'Literal'},
#       {'value': 'bos', 'raw': 'bos', '@type': 'Literal'},
#       {'value': 'woods', 'raw': 'woods', '@type': 'Literal'},
#       {'value': 'mand met vruchten',
#        'raw': 'mand met vruchten',
#        '@type': 'Literal'},
#       {'value': '66254', 'raw': '66254', '@type': 'Literal'},
#       {'value': 'Paulus Moreelse',
#        'raw': 'Paulus Moreelse',
#        '@type': 'Literal'},
#       {'value': '65455', 'raw': '65455', '@type': 'Literal'},
#       {'value': 'Romeinse mythologie',
#        'raw': 'Romeinse mythologie',
#        '@type': 'Literal'},
#       {'value': 'young woman', 'raw': 'young woman', '@type': 'Literal'},
#       {'value': '67292', 'raw': '67292', '@type': 'Literal'},
#       {'value': 'sickle', 'raw': 'sickle', '@type': 'Literal'},
#       {'value': 'Vertumnus, in the guise of an old woman, wooing Pomona',
#        'raw': 'Vertumnus, in the guise of an old woman, wooing Pomona',
#        '@type': 'Literal'},
#       {'value': 'sikkel', 'raw': 'sikkel', '@type': 'Literal'},
#       {'value': 'old woman', 'raw': 'old woman', '@type': 'Literal'}],
#      'spec': 'rkd-images',
#      'system': {'spec': 'rkd-images',
#       'graph_name': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-50725/graph',
#       'created_at': '2023-12-07T23:18:42+01:00',
#       'hasLandingPage': 'true',
#       'slug': 'dcn_rkd-images_https-rkd.nl-explore-images-50725',
#       'hasDeepZoom': 'false',
#       'hasDigitalObject': 'true',
#       'source_graph': '[{"@id":"http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-50725","@type":["http://www.openarchives.org/ore/terms/Aggregation"],"http://www.europeana.eu/schemas/edm/aggregatedCHO":[{"@id":"http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-50725"}],"http://www.europeana.eu/schemas/edm/dataProvider":[{"@value":"RKD – Nederlands Instituut voor Kunstgeschiedenis."}],"http://www.europeana.eu/schemas/edm/hasView":[{"@id":"_:b1"}],"http://www.europeana.eu/schemas/edm/isShownAt":[{"@id":"https://rkd.nl/explore/images/50725"}],"http://www.europeana.eu/schemas/edm/isShownBy":[{"@id":"https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc"},{"@id":"https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87"},{"@id":"https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200"}],"http://www.europeana.eu/schemas/edm/object":[{"@id":"https://rkd.nl/image/medium/8fd3f0f5-7e9e-1c1c-c9aa-2c59c19f80cc"},{"@id":"https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87"},{"@id":"https://rkd.nl/image/medium/3adec3fb-54c0-f432-55d2-68f5f7265200"}],"http://www.europeana.eu/schemas/edm/provider":[{"@value":"Rijksdienst voor het Cultureel Erfgoed"}],"http://www.europeana.eu/schemas/edm/rights":[{"@value":"http://www.europeana.eu/rights/unknown/"}],"http://www.openarchives.org/ore/terms/aggregates":[{"@id":"_:b2"},{"@id":"_:b0"}]},{"@id":"http://rkd.nl/explore/thesaurus?term=65455","@type":["http://www.w3.org/2004/02/skos/core#Concept"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"65455"},{"@value":"jonge vrouw"},{"@value":"young woman"}]},{"@id":"http://rkd.nl/explore/thesaurus?term=63655","@type":["http://www.w3.org/2004/02/skos/core#Concept"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"druif"},{"@value":"grape"},{"@value":"63655"}]},{"@id":"http://rkd.nl/explore/thesaurus?term=66254","@type":["http://www.w3.org/2004/02/skos/core#Concept"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"66254"},{"@value":"travestie"},{"@value":"travesty"}]},{"@id":"_:b0","@type":["http://schemas.delving.eu/nave/terms/DcnResource"],"http://schemas.delving.eu/nave/terms/material":[{"@language":"nl"}],"http://schemas.delving.eu/nave/terms/province":[{"@value":"Zuid-Holland"}]},{"@id":"http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-50725","@type":["http://www.europeana.eu/schemas/edm/ProvidedCHO"],"http://purl.org/dc/elements/1.1/creator":[{"@value":"Paulus Moreelse"}],"http://purl.org/dc/elements/1.1/date":[{"@value":"c. 1625-1630"}],"http://purl.org/dc/elements/1.1/subject":[{"@value":"woods","@language":"en"},{"@value":"bos","@language":"nl"},{"@value":"travestie","@language":"nl"},{"@value":"travesty","@language":"en"},{"@value":"grape","@language":"en"},{"@value":"63655"},{"@value":"basket with fruits","@language":"en"},{"@value":"Romeinse mythologie","@language":"nl"},{"@value":"66060"},{"@value":"mand met vruchten","@language":"nl"},{"@value":"Vertumnus, in the guise of an old woman, wooing Pomona","@language":"en"},{"@value":"62873"},{"@value":"young woman","@language":"en"},{"@value":"67292"},{"@value":"Roman mythology","@language":"en"},{"@value":"oude vrouw","@language":"nl"},{"@value":"63041"},{"@value":"66254"},{"@value":"65463"},{"@value":"old woman","@language":"en"},{"@value":"sikkel","@language":"nl"},{"@value":"druif","@language":"nl"},{"@value":"65455"},{"@value":"96A18211"},{"@value":"sickle","@language":"en"},{"@value":"jonge vrouw","@language":"nl"}],"http://purl.org/dc/elements/1.1/title":[{"@value":"Vertumnus and Pomona (Ovid, Met. XIV: 623)","@language":"en"},{"@value":"Vertumnus en Pomona (Ovidius, Metamorphoses XIV: 623)","@language":"nl"}],"http://purl.org/dc/elements/1.1/type":[{"@value":"schilderij","@language":"nl"}],"http://purl.org/dc/terms/created":[{"@value":"c. 1625-1630","@language":"en"}],"http://purl.org/dc/terms ...
#       'about_uri': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-50725',
#       'source_uri': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-50725',
#       'thumbnail': 'https://rkd.nl/image/medium/c7d808f5-de19-86b6-56d8-e0d699a00b87',
#       'preview': 'detail/foldout/void_edmrecord/dcn_rkd-images_https-rkd.nl-explore-images-50725',
#       'modified_at': '2023-12-07T23:18:42+01:00',
#       'hasGeoHash': 'false'}}}},
#   {'item': {'doc_id': 'dcn_rkd-images_https-rkd.nl-explore-images-250381',
#     'doc_type': 'void_edmrecord',
#     'fields': {'dc_creator': [{'value': 'Peter Paul Rubens',
#        'raw': 'Peter Paul Rubens',
#        '@type': 'Literal'},
#       {'value': 'Erasmus Quellinus (II)',
#        'raw': 'Erasmus Quellinus (II)',
#        '@type': 'Literal'}],
#      'dc_date': [{'value': 'after 1635',
#        'raw': 'after 1635',
#        '@type': 'Literal'}],
#      'dc_subject': [{'value': 'travesty',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'travesty'},
#       {'value': 'wapenrusting',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'wapenrusting'},
#       {'value': 'Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity'},
#       {'value': 'sieraad',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'sieraad'},
#       {'value': 'Greek mythology',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'Greek mythology'},
#       {'value': '94C22', 'raw': '94C22', '@type': 'Literal'},
#       {'value': '63212', 'raw': '63212', '@type': 'Literal'},
#       {'value': '63082', 'raw': '63082', '@type': 'Literal'},
#       {'value': '63039', 'raw': '63039', '@type': 'Literal'},
#       {'value': 'travestie',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'travestie'},
#       {'value': 'armor (protective wear)',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'armor (protective wear)'},
#       {'value': '66254', 'raw': '66254', '@type': 'Literal'},
#       {'value': 'paleis',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'paleis'},
#       {'value': 'Griekse mythologie',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'Griekse mythologie'},
#       {'value': '63716', 'raw': '63716', '@type': 'Literal'},
#       {'value': 'palace',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'palace'},
#       {'value': 'jewelry',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'jewelry'}],
#      'dc_title': [{'value': 'Achilles discovered among the daughters of Lycomedes',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'Achilles discovered among the daughters of Lycomedes'},
#       {'value': 'Achilles ontdekt tussen de dochters van Lycomedes',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'Achilles ontdekt tussen de dochters van Lycomedes'}],
#      'dc_type': [{'value': 'tekening',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'tekening'}],
#      'dcterms_created': [{'value': 'after 1635',
#        'language': 'en',
#        '@type': 'Literal',
#        'raw': 'after 1635'}],
#      'dcterms_medium': [{'value': 'zwart%20krijt',
#        'language': 'nl',
#        '@type': 'Literal',
#        'raw': 'zwart%20krijt'}],
#      'dcterms_provenance': [{'value': 'Laatst bekende of huidige verblijfplaats: Edinburgh, National Galleries Scotland, inv./cat.nr. D 1606',
#        'raw': 'Laatst bekende of huidige verblijfplaats: Edinburgh, National Galleries Scotland, inv./cat.nr. D 1606',
#        '@type': 'Literal'}],
#      'delving_spec': {'value': 'rkd-images',
#       'raw': 'rkd-images',
#       '@type': 'Literal'},
#      'edm_aggregatedCHO': [{'value': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-250381',
#        'id': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-250381',
#        '@type': 'URIRef',
#        'raw': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-250381'}],
#      'edm_dataProvider': [{'value': 'RKD – Nederlands Instituut voor Kunstgeschiedenis.',
#        'raw': 'RKD – Nederlands Instituut voor Kunstgeschiedenis.',
#        '@type': 'Literal'}],
#      'edm_hasView': [{'value': '_:b1',
#        'id': '_:b1',
#        '@type': 'URIRef',
#        'raw': '_:b1'}],
#      'edm_isShownAt': [{'value': 'https://rkd.nl/explore/images/250381',
#        'id': 'https://rkd.nl/explore/images/250381',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/explore/images/250381'}],
#      'edm_isShownBy': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        'id': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083'}],
#      'edm_object': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        'id': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        '@type': 'URIRef',
#        'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083'}],
#      'edm_provider': [{'value': 'Rijksdienst voor het Cultureel Erfgoed',
#        'raw': 'Rijksdienst voor het Cultureel Erfgoed',
#        '@type': 'Literal'}],
#      'edm_rights': [{'value': 'http://www.europeana.eu/rights/unknown/',
#        'raw': 'http://www.europeana.eu/rights/unknown/',
#        '@type': 'Literal'}],
#      'edm_type': [{'value': 'IMAGE', 'raw': 'IMAGE', '@type': 'Literal'}],
#      'entryURI': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-250381',
#      'foaf_name': [{'value': 'Erasmus Quellinus (II)',
#        'raw': 'Erasmus Quellinus (II)',
#        '@type': 'Literal'},
#       {'value': 'Peter Paul Rubens',
#        'raw': 'Peter Paul Rubens',
#        '@type': 'Literal'}],
#      'hubID': 'dcn_rkd-images_https-rkd.nl-explore-images-250381',
#      'legacy': {'delving_collection': 'rkd-images',
#       'delving_orgId': 'dcn',
#       'delving_hasGeoHash': 'false',
#       'delving_hasDeepZoom': 'false',
#       'delving_recordType': 'mdr',
#       'delving_spec': 'rkd-images',
#       'delving_hubId': 'dcn_rkd-images_https-rkd.nl-explore-images-250381',
#       'delving_hasLandingPage': 'true',
#       'delving_hasDigitalObject': 'true'},
#      'nave_allowDeepZoom': [{'value': 'true',
#        'raw': 'true',
#        '@type': 'Literal'}],
#      'nave_allowLinkedOpenData': [{'value': 'true',
#        'raw': 'true',
#        '@type': 'Literal'}],
#      'nave_allowSourceDownload': [{'value': 'false',
#        'raw': 'false',
#        '@type': 'Literal'}],
#      'nave_featured': [{'value': 'false', 'raw': 'false', '@type': 'Literal'}],
#      'nave_id': {'value': 'dcn_rkd-images_https-rkd.nl-explore-images-250381',
#       'raw': 'dcn_rkd-images_https-rkd.nl-explore-images-250381',
#       '@type': 'Literal'},
#      'nave_material': [{'language': 'nl', '@type': 'Literal'}],
#      'nave_province': [{'value': 'Zuid-Holland',
#        'raw': 'Zuid-Holland',
#        '@type': 'Literal'}],
#      'nave_public': [{'value': 'true', 'raw': 'true', '@type': 'Literal'}],
#      'nave_resourceSortOrder': [{'value': '1',
#        'raw': '1',
#        '@type': 'Literal'}],
#      'nave_thumbLarge': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        '@type': 'Literal'}],
#      'nave_thumbMedium': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#        '@type': 'Literal'}],
# ...
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Aafter 1628',
#      'isSelected': False,
#      'value': 'after 1628',
#      'count': 6,
#      'displayString': 'after 1628 (6)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1630-1635',
#      'isSelected': False,
#      'value': '1630-1635',
#      'count': 3,
#      'displayString': '1630-1635 (3)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1643 (dated)',
#      'isSelected': False,
#      'value': '1643 (dated)',
#      'count': 2,
#      'displayString': '1643 (dated) (2)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1913',
#      'isSelected': False,
#      'value': '1913',
#      'count': 2,
#      'displayString': '1913 (2)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1660',
#      'isSelected': False,
#      'value': 'c. 1660',
#      'count': 2,
#      'displayString': 'c. 1660 (2)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1700',
#      'isSelected': False,
#      'value': 'c. 1700',
#      'count': 2,
#      'displayString': 'c. 1700 (2)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Adated 1635',
#      'isSelected': False,
#      'value': 'dated 1635',
#      'count': 2,
#      'displayString': 'dated 1635 (2)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1611 (dated)',
#      'isSelected': False,
#      'value': '1611 (dated)',
#      'count': 1,
#      'displayString': '1611 (dated) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1617 (dated)',
#      'isSelected': False,
#      'value': '1617 (dated)',
#      'count': 1,
#      'displayString': '1617 (dated) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1620 (dated)',
#      'isSelected': False,
#      'value': '1620 (dated)',
#      'count': 1,
#      'displayString': '1620 (dated) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1625-1635',
#      'isSelected': False,
#      'value': '1625-1635',
#      'count': 1,
#      'displayString': '1625-1635 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1628 (dated)',
#      'isSelected': False,
#      'value': '1628 (dated)',
#      'count': 1,
#      'displayString': '1628 (dated) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1629 (dated)',
#      'isSelected': False,
#      'value': '1629 (dated)',
#      'count': 1,
#      'displayString': '1629 (dated) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A164..? (dated)',
#      'isSelected': False,
#      'value': '164..? (dated)',
#      'count': 1,
#      'displayString': '164..? (dated) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1644 (dated)',
#      'isSelected': False,
#      'value': '1644 (dated)',
#      'count': 1,
#      'displayString': '1644 (dated) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1650-1655',
#      'isSelected': False,
#      'value': '1650-1655',
#      'count': 1,
#      'displayString': '1650-1655 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1650s',
#      'isSelected': False,
#      'value': '1650s',
#      'count': 1,
#      'displayString': '1650s (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1719',
#      'isSelected': False,
#      'value': '1719',
#      'count': 1,
#      'displayString': '1719 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1728 (dated)',
#      'isSelected': False,
#      'value': '1728 (dated)',
#      'count': 1,
#      'displayString': '1728 (dated) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1730',
#      'isSelected': False,
#      'value': '1730',
#      'count': 1,
#      'displayString': '1730 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1735 (dated)',
#      'isSelected': False,
#      'value': '1735 (dated)',
#      'count': 1,
#      'displayString': '1735 (dated) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1769 (dated)',
#      'isSelected': False,
#      'value': '1769 (dated)',
#      'count': 1,
#      'displayString': '1769 (dated) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1912',
#      'isSelected': False,
#      'value': '1912',
#      'count': 1,
#      'displayString': '1912 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3A1993 (dated)',
#      'isSelected': False,
#      'value': '1993 (dated)',
#      'count': 1,
#      'displayString': '1993 (dated) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Aafte r1630',
#      'isSelected': False,
#      'value': 'afte r1630',
#      'count': 1,
#      'displayString': 'afte r1630 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Aafter 1617',
#      'isSelected': False,
#      'value': 'after 1617',
#      'count': 1,
#      'displayString': 'after 1617 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Aafter 1643',
#      'isSelected': False,
#      'value': 'after 1643',
#      'count': 1,
#      'displayString': 'after 1643 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Aafter 1658',
#      'isSelected': False,
#      'value': 'after 1658',
#      'count': 1,
#      'displayString': 'after 1658 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1567-1568',
#      'isSelected': False,
#      'value': 'c. 1567-1568',
#      'count': 1,
#      'displayString': 'c. 1567-1568 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1620',
#      'isSelected': False,
#      'value': 'c. 1620',
#      'count': 1,
#      'displayString': 'c. 1620 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1620-1630',
#      'isSelected': False,
#      'value': 'c. 1620-1630',
#      'count': 1,
#      'displayString': 'c. 1620-1630 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1623-1625',
#      'isSelected': False,
#      'value': 'c. 1623-1625',
#      'count': 1,
#      'displayString': 'c. 1623-1625 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1624',
#      'isSelected': False,
#      'value': 'c. 1624',
#      'count': 1,
#      'displayString': 'c. 1624 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1625-1630',
#      'isSelected': False,
#      'value': 'c. 1625-1630',
#      'count': 1,
#      'displayString': 'c. 1625-1630 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1628-1629',
#      'isSelected': False,
#      'value': 'c. 1628-1629',
#      'count': 1,
#      'displayString': 'c. 1628-1629 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1635-1637',
#      'isSelected': False,
#      'value': 'c. 1635-1637',
#      'count': 1,
#      'displayString': 'c. 1635-1637 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1637-1640',
#      'isSelected': False,
#      'value': 'c. 1637-1640',
#      'count': 1,
#      'displayString': 'c. 1637-1640 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1640',
#      'isSelected': False,
#      'value': 'c. 1640',
#      'count': 1,
#      'displayString': 'c. 1640 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1640-1645',
#      'isSelected': False,
#      'value': 'c. 1640-1645',
#      'count': 1,
#      'displayString': 'c. 1640-1645 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1640-1660',
#      'isSelected': False,
#      'value': 'c. 1640-1660',
#      'count': 1,
#      'displayString': 'c. 1640-1660 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1665-1675',
#      'isSelected': False,
#      'value': 'c. 1665-1675',
#      'count': 1,
#      'displayString': 'c. 1665-1675 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1675, mogelijk first half zeventig (167. (dated))',
#      'isSelected': False,
#      'value': 'c. 1675, mogelijk first half zeventig (167. (dated))',
#      'count': 1,
#      'displayString': 'c. 1675, mogelijk first half zeventig (167. (dated)) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1675-160',
#      'isSelected': False,
#      'value': 'c. 1675-160',
#      'count': 1,
#      'displayString': 'c. 1675-160 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1690',
#      'isSelected': False,
#      'value': 'c. 1690',
#      'count': 1,
#      'displayString': 'c. 1690 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1720',
#      'isSelected': False,
#      'value': 'c. 1720',
#      'count': 1,
#      'displayString': 'c. 1720 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Ac. 1730',
#      'isSelected': False,
#      'value': 'c. 1730',
#      'count': 1,
#      'displayString': 'c. 1730 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Aca. 1635',
#      'isSelected': False,
#      'value': 'ca. 1635',
#      'count': 1,
#      'displayString': 'ca. 1635 (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_date_facet%3Aca. 1979',
#      'isSelected': False,
#      'value': 'ca. 1979',
#      'count': 1,
#      'displayString': 'ca. 1979 (1)'}]},
#   {'name': 'dc_type_facet',
#    'isSelected': False,
#    'i18n': 'Soort object',
#    'total': 12,
#    'missingDocs': 0,
#    'otherDocs': 0,
#    'links': [{'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3Aschilderij',
#      'isSelected': False,
#      'value': 'schilderij',
#      'count': 105,
#      'displayString': 'schilderij (105)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3Atekening',
#      'isSelected': False,
#      'value': 'tekening',
#      'count': 19,
#      'displayString': 'tekening (19)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3ANegatief (zwart/wit)',
#      'isSelected': False,
#      'value': 'Negatief (zwart/wit)',
#      'count': 7,
#      'displayString': 'Negatief (zwart/wit) (7)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3Afoto',
#      'isSelected': False,
#      'value': 'foto',
#      'count': 7,
#      'displayString': 'foto (7)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3Areproductieprent',
#      'isSelected': False,
#      'value': 'reproductieprent',
#      'count': 4,
#      'displayString': 'reproductieprent (4)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3Abovendeurstuk',
#      'isSelected': False,
#      'value': 'bovendeurstuk',
#      'count': 2,
#      'displayString': 'bovendeurstuk (2)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3Adecoratiestuk',
#      'isSelected': False,
#      'value': 'decoratiestuk',
#      'count': 2,
#      'displayString': 'decoratiestuk (2)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3Aolieverfschets',
#      'isSelected': False,
#      'value': 'olieverfschets',
#      'count': 2,
#      'displayString': 'olieverfschets (2)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3Aportretminiatuur',
#      'isSelected': False,
#      'value': 'portretminiatuur',
#      'count': 2,
#      'displayString': 'portretminiatuur (2)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3Akarton (werktekening)',
#      'isSelected': False,
#      'value': 'karton (werktekening)',
#      'count': 1,
#      'displayString': 'karton (werktekening) (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3Amodello',
#      'isSelected': False,
#      'value': 'modello',
#      'count': 1,
#      'displayString': 'modello (1)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_type_facet%3Aprent',
#      'isSelected': False,
#      'value': 'prent',
#      'count': 1,
#      'displayString': 'prent (1)'}]},
#   {'name': 'nave_material_facet',
#    'isSelected': False,
#    'i18n': 'Materiaal',
#    'total': 4,
#    'missingDocs': 0,
#    'otherDocs': 0,
#    'links': [{'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=nave_material_facet%3Apapier',
#      'isSelected': False,
#      'value': 'papier',
#      'count': 7,
#      'displayString': 'papier (7)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=nave_material_facet%3Abarietpapier',
#      'isSelected': False,
#      'value': 'barietpapier',
#      'count': 4,
#      'displayString': 'barietpapier (4)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=nave_material_facet%3APapier',
#      'isSelected': False,
#      'value': 'Papier',
#      'count': 3,
#      'displayString': 'Papier (3)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=nave_material_facet%3Ape-papier',
#      'isSelected': False,
#      'value': 'pe-papier',
#      'count': 3,
#      'displayString': 'pe-papier (3)'}]},
#   {'name': 'nave_city_facet',
#    'isSelected': False,
#    'i18n': 'nave_city',
#    'total': 0,
#    'missingDocs': 0,
#    'otherDocs': 0,
#    'links': []},
#   {'name': 'nave_technique_facet',
#    'isSelected': False,
#    'i18n': 'Techniek',
#    'total': 4,
#    'missingDocs': 0,
#    'otherDocs': 0,
#    'links': [{'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=nave_technique_facet%3Aafgedrukt',
#      'isSelected': False,
#      'value': 'afgedrukt',
#      'count': 7,
#      'displayString': 'afgedrukt (7)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=nave_technique_facet%3Agefotografeerd',
#      'isSelected': False,
#      'value': 'gefotografeerd',
#      'count': 7,
#      'displayString': 'gefotografeerd (7)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=nave_technique_facet%3ALitho',
#      'isSelected': False,
#      'value': 'Litho',
#      'count': 2,
#      'displayString': 'Litho (2)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=nave_technique_facet%3AHoogdruk',
#      'isSelected': False,
#      'value': 'Hoogdruk',
#      'count': 1,
#      'displayString': 'Hoogdruk (1)'}]},
#   {'name': 'dc_rights_facet',
#    'isSelected': False,
#    'i18n': 'Rechten',
#    'total': 3,
#    'missingDocs': 0,
#    'otherDocs': 0,
#    'links': [{'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_rights_facet%3Ahttps%3A//creativecommons.org/licenses/by/4.0/deed.nl',
#      'isSelected': False,
#      'value': 'https://creativecommons.org/licenses/by/4.0/deed.nl',
#      'count': 7,
#      'displayString': 'https://creativecommons.org/licenses/by/4.0/deed.nl (7)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_rights_facet%3A© Joods Historisch Museum, Amsterdam',
#      'isSelected': False,
#      'value': '© Joods Historisch Museum, Amsterdam',
#      'count': 7,
#      'displayString': '© Joods Historisch Museum, Amsterdam (7)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=dc_rights_facet%3APubliek Domein',
#      'isSelected': False,
#      'value': 'Publiek Domein',
#      'count': 3,
#      'displayString': 'Publiek Domein (3)'}]},
#   {'name': 'edm_rights_facet',
#    'isSelected': False,
#    'i18n': 'Rechten',
#    'total': 3,
#    'missingDocs': 0,
#    'otherDocs': 0,
#    'links': [{'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=edm_rights_facet%3Ahttp%3A//www.europeana.eu/rights/unknown/',
#      'isSelected': False,
#      'value': 'http://www.europeana.eu/rights/unknown/',
#      'count': 139,
#      'displayString': 'http://www.europeana.eu/rights/unknown/ (139)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=edm_rights_facet%3Ahttp%3A//rightsstatements.org/vocab/InC/1.0/',
#      'isSelected': False,
#      'value': 'http://rightsstatements.org/vocab/InC/1.0/',
#      'count': 10,
#      'displayString': 'http://rightsstatements.org/vocab/InC/1.0/ (10)'},
#     {'url': '&qf[]=dc_subject_facet%3Atravestie&qf[]=edm_rights_facet%3Ahttp%3A//www.europeana.eu/portal/rights/rr-f',
#      'isSelected': False,
#      'value': 'http://www.europeana.eu/portal/rights/rr-f',
#      'count': 7,
#      'displayString': 'http://www.europeana.eu/portal/rights/rr-f (7)'}]}]}

# %%
hits['result']['items'][0]
# Out:
# {'item': {'doc_id': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#   'doc_type': 'void_edmrecord',
#   'fields': {'dc_creator': [{'value': 'Cornelis Kruseman',
#      'raw': 'Cornelis Kruseman',
#      '@type': 'Literal'}],
#    'dc_subject': [{'value': 'Greek mythology',
#      'language': 'en',
#      '@type': 'Literal',
#      'raw': 'Greek mythology'},
#     {'value': 'woman', 'language': 'en', '@type': 'Literal', 'raw': 'woman'},
#     {'value': '66254', 'raw': '66254', '@type': 'Literal'},
#     {'value': 'Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity',
#      'language': 'en',
#      '@type': 'Literal',
#      'raw': 'Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity'},
#     {'value': 'Griekse mythologie',
#      'language': 'nl',
#      '@type': 'Literal',
#      'raw': 'Griekse mythologie'},
#     {'value': '94C22', 'raw': '94C22', '@type': 'Literal'},
#     {'value': '63039', 'raw': '63039', '@type': 'Literal'},
#     {'value': 'travesty',
#      'language': 'en',
#      '@type': 'Literal',
#      'raw': 'travesty'},
#     {'value': '63173', 'raw': '63173', '@type': 'Literal'},
#     {'value': 'travestie',
#      'language': 'nl',
#      '@type': 'Literal',
#      'raw': 'travestie'},
#     {'value': 'vrouw', 'language': 'nl', '@type': 'Literal', 'raw': 'vrouw'}],
#    'dc_title': [{'value': 'Achilles onder de maagden (te Rome, Galerie Faesch)',
#      'language': 'nl',
#      '@type': 'Literal',
#      'raw': 'Achilles onder de maagden (te Rome, Galerie Faesch)'},
#     {'value': 'Achilles with the virgins',
#      'language': 'en',
#      '@type': 'Literal',
#      'raw': 'Achilles with the virgins'}],
#    'dc_type': [{'value': 'olieverfschets',
#      'language': 'nl',
#      '@type': 'Literal',
#      'raw': 'olieverfschets'}],
#    'dcterms_created': [{'language': 'en', '@type': 'Literal'}],
#    'dcterms_medium': [{'value': 'olieverf',
#      'language': 'nl',
#      '@type': 'Literal',
#      'raw': 'olieverf'}],
#    'dcterms_provenance': [{'value': 'Laatst bekende of huidige verblijfplaats: Cornelis François Roos (Amsterdam (city)) 1858-02-16 - 1858-02-18, nr. 13, p. 23',
#      'raw': 'Laatst bekende of huidige verblijfplaats: Cornelis François Roos (Amsterdam (city)) 1858-02-16 - 1858-02-18, nr. 13, p. 23',
#      '@type': 'Literal'}],
#    'delving_spec': {'value': 'rkd-images',
#     'raw': 'rkd-images',
#     '@type': 'Literal'},
#    'edm_aggregatedCHO': [{'value': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-266646',
#      'id': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-266646',
#      '@type': 'URIRef',
#      'raw': 'http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-266646'}],
#    'edm_dataProvider': [{'value': 'RKD – Nederlands Instituut voor Kunstgeschiedenis.',
#      'raw': 'RKD – Nederlands Instituut voor Kunstgeschiedenis.',
#      '@type': 'Literal'}],
#    'edm_hasView': [{'value': '_:b1',
#      'id': '_:b1',
#      '@type': 'URIRef',
#      'raw': '_:b1'}],
#    'edm_isShownAt': [{'value': 'https://rkd.nl/explore/images/266646',
#      'id': 'https://rkd.nl/explore/images/266646',
#      '@type': 'URIRef',
#      'raw': 'https://rkd.nl/explore/images/266646'}],
#    'edm_isShownBy': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#      'id': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#      '@type': 'URIRef',
#      'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083'}],
#    'edm_object': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#      'id': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#      '@type': 'URIRef',
#      'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083'}],
#    'edm_provider': [{'value': 'Rijksdienst voor het Cultureel Erfgoed',
#      'raw': 'Rijksdienst voor het Cultureel Erfgoed',
#      '@type': 'Literal'}],
#    'edm_rights': [{'value': 'http://www.europeana.eu/rights/unknown/',
#      'raw': 'http://www.europeana.eu/rights/unknown/',
#      '@type': 'Literal'}],
#    'edm_type': [{'value': 'IMAGE', 'raw': 'IMAGE', '@type': 'Literal'}],
#    'entryURI': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-266646',
#    'foaf_name': [{'value': 'Cornelis Kruseman',
#      'raw': 'Cornelis Kruseman',
#      '@type': 'Literal'}],
#    'hubID': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#    'legacy': {'delving_collection': 'rkd-images',
#     'delving_orgId': 'dcn',
#     'delving_hasGeoHash': 'false',
#     'delving_hasDeepZoom': 'false',
#     'delving_recordType': 'mdr',
#     'delving_spec': 'rkd-images',
#     'delving_hubId': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#     'delving_hasLandingPage': 'true',
#     'delving_hasDigitalObject': 'true'},
#    'nave_allowDeepZoom': [{'value': 'true',
#      'raw': 'true',
#      '@type': 'Literal'}],
#    'nave_allowLinkedOpenData': [{'value': 'true',
#      'raw': 'true',
#      '@type': 'Literal'}],
#    'nave_allowSourceDownload': [{'value': 'false',
#      'raw': 'false',
#      '@type': 'Literal'}],
#    'nave_featured': [{'value': 'false', 'raw': 'false', '@type': 'Literal'}],
#    'nave_id': {'value': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#     'raw': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#     '@type': 'Literal'},
#    'nave_material': [{'language': 'nl', '@type': 'Literal'}],
#    'nave_province': [{'value': 'Zuid-Holland',
#      'raw': 'Zuid-Holland',
#      '@type': 'Literal'}],
#    'nave_public': [{'value': 'true', 'raw': 'true', '@type': 'Literal'}],
#    'nave_resourceSortOrder': [{'value': '1', 'raw': '1', '@type': 'Literal'}],
#    'nave_thumbLarge': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#      'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#      '@type': 'Literal'}],
#    'nave_thumbMedium': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#      'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#      '@type': 'Literal'}],
#    'nave_thumbSmall': [{'value': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#      'raw': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#      '@type': 'Literal'}],
#    'ore_aggregates': [{'value': 'b2',
#      'id': 'b2',
#      '@type': 'Bnode',
#      'raw': 'b2'},
#     {'value': 'b0', 'id': 'b0', '@type': 'Bnode', 'raw': 'b0'}],
#    'orgID': 'dcn',
#    'rdf_type': [{'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#      'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#      '@type': 'URIRef',
#      'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#     {'value': 'http://www.europeana.eu/schemas/edm/Agent',
#      'id': 'http://www.europeana.eu/schemas/edm/Agent',
#      '@type': 'URIRef',
#      'raw': 'http://www.europeana.eu/schemas/edm/Agent'},
#     {'value': 'http://schemas.delving.eu/nave/terms/DelvingResource',
#      'id': 'http://schemas.delving.eu/nave/terms/DelvingResource',
#      '@type': 'URIRef',
#      'raw': 'http://schemas.delving.eu/nave/terms/DelvingResource'},
#     {'value': 'http://schemas.delving.eu/nave/terms/DcnResource',
#      'id': 'http://schemas.delving.eu/nave/terms/DcnResource',
#      '@type': 'URIRef',
#      'raw': 'http://schemas.delving.eu/nave/terms/DcnResource'},
#     {'value': 'http://www.europeana.eu/schemas/edm/ProvidedCHO',
#      'id': 'http://www.europeana.eu/schemas/edm/ProvidedCHO',
#      '@type': 'URIRef',
#      'raw': 'http://www.europeana.eu/schemas/edm/ProvidedCHO'},
#     {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#      'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#      '@type': 'URIRef',
#      'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#     {'value': 'http://www.openarchives.org/ore/terms/Aggregation',
#      'id': 'http://www.openarchives.org/ore/terms/Aggregation',
#      '@type': 'URIRef',
#      'raw': 'http://www.openarchives.org/ore/terms/Aggregation'},
#     {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#      'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#      '@type': 'URIRef',
#      'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#     {'value': 'http://www.w3.org/2004/02/skos/core#Concept',
#      'id': 'http://www.w3.org/2004/02/skos/core#Concept',
#      '@type': 'URIRef',
#      'raw': 'http://www.w3.org/2004/02/skos/core#Concept'},
#     {'value': 'http://www.europeana.eu/schemas/edm/WebResource',
#      'id': 'http://www.europeana.eu/schemas/edm/WebResource',
#      '@type': 'URIRef',
#      'raw': 'http://www.europeana.eu/schemas/edm/WebResource'}],
#    'revision': 123,
#    'skos_prefLabel': [{'value': 'Griekse mythologie',
#      'raw': 'Griekse mythologie',
#      '@type': 'Literal'},
#     {'value': 'travesty', 'raw': 'travesty', '@type': 'Literal'},
#     {'value': 'Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity',
#      'raw': 'Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity',
#      '@type': 'Literal'},
#     {'value': '63173', 'raw': '63173', '@type': 'Literal'},
#     {'value': 'Cornelis Kruseman',
#      'raw': 'Cornelis Kruseman',
#      '@type': 'Literal'},
#     {'value': '94C22', 'raw': '94C22', '@type': 'Literal'},
#     {'value': 'Greek mythology', 'raw': 'Greek mythology', '@type': 'Literal'},
#     {'value': 'woman', 'raw': 'woman', '@type': 'Literal'},
#     {'value': '63039', 'raw': '63039', '@type': 'Literal'},
#     {'value': 'vrouw', 'raw': 'vrouw', '@type': 'Literal'},
#     {'value': '66254', 'raw': '66254', '@type': 'Literal'},
#     {'value': 'travestie', 'raw': 'travestie', '@type': 'Literal'}],
#    'spec': 'rkd-images',
#    'system': {'spec': 'rkd-images',
#     'graph_name': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-266646/graph',
#     'created_at': '2023-12-07T23:23:19+01:00',
#     'hasLandingPage': 'true',
#     'slug': 'dcn_rkd-images_https-rkd.nl-explore-images-266646',
#     'hasDeepZoom': 'false',
#     'hasDigitalObject': 'true',
#     'source_graph': '[{"@id":"http://opendata.rkd.nl/opensearch/artists/eac-cpf?q=kunstenaarsnummer:46663","@type":["http://www.europeana.eu/schemas/edm/Agent"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"Cornelis Kruseman"}],"http://xmlns.com/foaf/0.1/name":[{"@value":"Cornelis Kruseman"}]},{"@id":"_:b2","@type":["http://schemas.delving.eu/nave/terms/DelvingResource"],"http://schemas.delving.eu/nave/terms/allowDeepZoom":[{"@value":"true"}],"http://schemas.delving.eu/nave/terms/allowLinkedOpenData":[{"@value":"true"}],"http://schemas.delving.eu/nave/terms/allowSourceDownload":[{"@value":"false"}],"http://schemas.delving.eu/nave/terms/featured":[{"@value":"false"}],"http://schemas.delving.eu/nave/terms/public":[{"@value":"true"}]},{"@id":"http://www.iconclass.org/rkd/94C22","@type":["http://www.w3.org/2004/02/skos/core#Concept"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity"},{"@value":"94C22"}]},{"@id":"_:b0","@type":["http://schemas.delving.eu/nave/terms/DcnResource"],"http://schemas.delving.eu/nave/terms/material":[{"@language":"nl"}],"http://schemas.delving.eu/nave/terms/province":[{"@value":"Zuid-Holland"}]},{"@id":"http://rkd.nl/explore/thesaurus?term=66254","@type":["http://www.w3.org/2004/02/skos/core#Concept"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"travestie"},{"@value":"66254"},{"@value":"travesty"}]},{"@id":"http://rkd.nl/explore/thesaurus?term=63173","@type":["http://www.w3.org/2004/02/skos/core#Concept"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"vrouw"},{"@value":"woman"},{"@value":"63173"}]},{"@id":"http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-266646","@type":["http://www.openarchives.org/ore/terms/Aggregation"],"http://www.europeana.eu/schemas/edm/aggregatedCHO":[{"@id":"http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-266646"}],"http://www.europeana.eu/schemas/edm/dataProvider":[{"@value":"RKD – Nederlands Instituut voor Kunstgeschiedenis."}],"http://www.europeana.eu/schemas/edm/hasView":[{"@id":"_:b1"}],"http://www.europeana.eu/schemas/edm/isShownAt":[{"@id":"https://rkd.nl/explore/images/266646"}],"http://www.europeana.eu/schemas/edm/isShownBy":[{"@id":"https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083"}],"http://www.europeana.eu/schemas/edm/object":[{"@id":"https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083"}],"http://www.europeana.eu/schemas/edm/provider":[{"@value":"Rijksdienst voor het Cultureel Erfgoed"}],"http://www.europeana.eu/schemas/edm/rights":[{"@value":"http://www.europeana.eu/rights/unknown/"}],"http://www.openarchives.org/ore/terms/aggregates":[{"@id":"_:b2"},{"@id":"_:b0"}]},{"@id":"http://rkd.nl/explore/thesaurus?term=63039","@type":["http://www.w3.org/2004/02/skos/core#Concept"],"http://www.w3.org/2004/02/skos/core#prefLabel":[{"@value":"Griekse mythologie"},{"@value":"Greek mythology"},{"@value":"63039"}]},{"@id":"http://data.collectienederland.nl/resource/document/rkd-images/https-rkd.nl-explore-images-266646","@type":["http://www.europeana.eu/schemas/edm/ProvidedCHO"],"http://purl.org/dc/elements/1.1/creator":[{"@value":"Cornelis Kruseman"}],"http://purl.org/dc/elements/1.1/subject":[{"@value":"woman","@language":"en"},{"@value":"94C22"},{"@value":"Achilles discovered among the daughters of Lycomedes, i.e. Achilles on Scyros: when presents are brought Achilles snatches up the weapons and thus betrays his identity","@language":"en"},{"@value":"63173"},{"@value":"travestie","@language":"nl"},{"@value":"travesty","@language":"en"},{"@value":"66254"},{"@value":"Griekse mythologie","@language":"nl"},{"@value":"vrouw","@language":"nl"},{"@value":"Greek mythology","@language":"en"},{"@value":"63039"}],"http://purl.org/dc/elements/1.1/title":[{"@v ...
#     'about_uri': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-266646',
#     'source_uri': 'http://data.collectienederland.nl/resource/aggregation/rkd-images/https-rkd.nl-explore-images-266646',
#     'thumbnail': 'https://rkd.nl/image/medium/0d963e21-f176-d222-e878-6b5871220083',
#     'preview': 'detail/foldout/void_edmrecord/dcn_rkd-images_https-rkd.nl-explore-images-266646',
#     'modified_at': '2023-12-07T23:23:19+01:00',
#     'hasGeoHash': 'false'}}}}

# %%
for item in hits['result']['items']:
    print(item['item']['fields'])
    break
# Out:
# {'dc_coverage': [{'value': 'Amsterdam & Nederland', 'raw': 'Amsterdam & Nederland', '@type': 'Literal'}], 'dc_creator': [{'value': 'Wesly, Jenny E. (1948-2016)', 'raw': 'Wesly, Jenny E. (1948-2016)', '@type': 'Literal'}, {'value': 'Brugmans, Erwin (1950-2020)', 'raw': 'Brugmans, Erwin (1950-2020)', '@type': 'Literal'}, {'value': 'Nieuwkoop, David', 'raw': 'Nieuwkoop, David', '@type': 'Literal'}], 'dc_description': [{'value': 'Twee jongemannen in travestie. Beiden dragen een pruik en oorbellen.', 'raw': 'Twee jongemannen in travestie. Beiden dragen een pruik en oorbellen.', '@type': 'Literal'}], 'dc_identifier': [{'value': 'M013694', 'raw': 'M013694', '@type': 'Literal'}], 'dc_rights': [{'value': '© Joods Historisch Museum, Amsterdam', 'raw': '© Joods Historisch Museum, Amsterdam', '@type': 'Literal'}], 'dc_source': [{'value': 'Joods Museum', 'raw': 'Joods Museum', '@type': 'Literal'}], 'dc_subject': [{'value': 'Wesly, Jenny E. (1948-2016)', 'raw': 'Wesly, Jenny E. (1948-2016)', '@type': 'Literal'}, {'value': 'Sjalhomo', 'raw': 'Sjalhomo', '@type': 'Literal'}, {'value': "Café l'Opera", 'raw': "Café l'Opera", '@type': 'Literal'}, {'value': 'Nieuwkoop, David', 'raw': 'Nieuwkoop, David', '@type': 'Literal'}, {'value': 'Amsterdam', 'raw': 'Amsterdam', '@type': 'Literal'}, {'value': 'belangenorganisatie', 'raw': 'belangenorganisatie', '@type': 'Literal'}, {'value': 'Poeriem', 'raw': 'Poeriem', '@type': 'Literal'}, {'value': 'Brugmans, Erwin (1950-2020)', 'raw': 'Brugmans, Erwin (1950-2020)', '@type': 'Literal'}, {'value': 'homoseksualiteit', 'raw': 'homoseksualiteit', '@type': 'Literal'}, {'value': 'travestie', 'raw': 'travestie', '@type': 'Literal'}], 'dc_title': [{'value': "Poeriem in Café de l'Opera, twee mannen in travestie", 'raw': "Poeriem in Café de l'Opera, twee mannen in travestie", '@type': 'Literal'}], 'dc_type': [{'value': 'foto', 'raw': 'foto', '@type': 'Literal'}], 'dcterms_alternative': [{'value': 'M013694, foto, Jenny E. Wesly, 1993-03-06', 'raw': 'M013694, foto, Jenny E. Wesly, 1993-03-06', '@type': 'Literal'}], 'dcterms_created': [{'value': '1993-03-06', 'raw': '1993-03-06', '@type': 'Literal'}], 'dcterms_extent': [{'value': 'hoogte 27.7 cm', 'raw': 'hoogte 27.7 cm', '@type': 'Literal'}, {'value': 'breedte 35.3 cm', 'raw': 'breedte 35.3 cm', '@type': 'Literal'}], 'dcterms_medium': [{'value': 'papier', 'raw': 'papier', '@type': 'Literal'}, {'value': 'barietpapier', 'raw': 'barietpapier', '@type': 'Literal'}], 'delving_spec': {'value': 'joods-historisch', 'raw': 'joods-historisch', '@type': 'Literal'}, 'edm_aggregatedCHO': [{'value': 'http://data.collectienederland.nl/resource/document/joods-historisch/M013694', 'id': 'http://data.collectienederland.nl/resource/document/joods-historisch/M013694', '@type': 'URIRef', 'raw': 'http://data.collectienederland.nl/resource/document/joods-historisch/M013694'}], 'edm_dataProvider': [{'value': 'Joods Historisch Museum', 'raw': 'Joods Historisch Museum', '@type': 'Literal'}], 'edm_hasMet': [{'value': 'http://data.jck.nl/resource/skos/thespersoon/29805', 'id': 'http://data.jck.nl/resource/skos/thespersoon/29805', '@type': 'URIRef', 'raw': 'http://data.jck.nl/resource/skos/thespersoon/29805'}, {'value': 'http://data.jck.nl/resource/skos/thespersoon/105588', 'id': 'http://data.jck.nl/resource/skos/thespersoon/105588', '@type': 'URIRef', 'raw': 'http://data.jck.nl/resource/skos/thespersoon/105588'}], 'edm_isShownAt': [{'value': 'http://data.jck.nl/resource/aggregation/jhm-museum/M013694', 'id': 'http://data.jck.nl/resource/aggregation/jhm-museum/M013694', '@type': 'URIRef', 'raw': 'http://data.jck.nl/resource/aggregation/jhm-museum/M013694'}], 'edm_isShownBy': [{'value': 'https://media.delving.org/thumbnail/jck/joods-historisch/d729/729NM013694/1000', 'raw': 'https://media.delving.org/thumbnail/jck/joods-historisch/d729/729NM013694/1000', '@type': 'Literal'}], 'edm_object': [{'value': 'https://media.delving.org/thumbnail/jck/joods-historisch/d729/729NM013694/1000', 'raw': 'https://m ...

# %% [markdown]
# ### a single record metadata (json-ld)

# %%
with open("/Users/anesterov/Downloads/M013571.json-ld.json",'r') as jf:
    record = json.load(jf)

# %%
record
# Out:
# [{'@id': 'http://data.collectienederland.nl/resource/document/joods-historisch/M013571',
#   '@type': ['http://www.europeana.eu/schemas/edm/ProvidedCHO'],
#   'http://purl.org/dc/elements/1.1/coverage': [{'@value': 'Nederland'}],
#   'http://purl.org/dc/elements/1.1/creator': [{'@value': 'Wesly, Jenny E. (1948-2016)'}],
#   'http://purl.org/dc/elements/1.1/description': [{'@value': 'Een groep demonstrerende mannen en vrouwen op een zomerse dag. Ze dragen spandoeken met zich mee.'}],
#   'http://purl.org/dc/elements/1.1/identifier': [{'@value': 'M013571'}],
#   'http://purl.org/dc/elements/1.1/source': [{'@value': 'Joods Museum'}],
#   'http://purl.org/dc/elements/1.1/subject': [{'@value': 'Utrecht (stad)'},
#    {'@value': 'demonstratie'},
#    {'@value': 'homoseksualiteit'},
#    {'@value': 'belangenorganisatie'},
#    {'@value': 'Wesly, Jenny E. (1948-2016)'},
#    {'@value': 'Sjalhomo'},
#    {'@value': 'spandoek'},
#    {'@value': 'portret'}],
#   'http://purl.org/dc/elements/1.1/title': [{'@value': 'Sjalhomo op Roze Zaterdag, de nationale homodag, 28 juni 1986'}],
#   'http://purl.org/dc/elements/1.1/type': [{'@value': 'foto'}],
#   'http://purl.org/dc/terms/alternative': [{'@value': 'M013571, foto, Jenny E. Wesly, 1986-06-28'}],
#   'http://purl.org/dc/terms/created': [{'@value': '1986-06-28'}],
#   'http://purl.org/dc/terms/extent': [{'@value': 'hoogte 27.9 cm'},
#    {'@value': 'breedte 35.3 cm'}],
#   'http://purl.org/dc/terms/medium': [{'@value': 'barietpapier'},
#    {'@value': 'papier'}],
#   'http://www.europeana.eu/schemas/edm/type': [{'@value': 'IMAGE'}]},
#  {'@id': 'http://data.collectienederland.nl/resource/aggregation/joods-historisch/M013571',
#   '@type': ['http://www.openarchives.org/ore/terms/Aggregation'],
#   'http://purl.org/dc/elements/1.1/rights': [{'@value': '© Joods Historisch Museum, Amsterdam'}],
#   'http://www.europeana.eu/schemas/edm/aggregatedCHO': [{'@id': 'http://data.collectienederland.nl/resource/document/joods-historisch/M013571'}],
#   'http://www.europeana.eu/schemas/edm/dataProvider': [{'@value': 'Joods Historisch Museum'}],
#   'http://www.europeana.eu/schemas/edm/isShownAt': [{'@id': 'http://data.jck.nl/resource/aggregation/jhm-museum/M013571'}],
#   'http://www.europeana.eu/schemas/edm/isShownBy': [{'@value': 'https://media.delving.org/thumbnail/jck/joods-historisch/d729/729NM013571/1000'}],
#   'http://www.europeana.eu/schemas/edm/object': [{'@value': 'https://media.delving.org/thumbnail/jck/joods-historisch/d729/729NM013571/1000'}],
#   'http://www.europeana.eu/schemas/edm/provider': [{'@value': 'Rijksdienst voor het Cultureel Erfgoed'}],
#   'http://www.europeana.eu/schemas/edm/rights': [{'@id': 'http://rightsstatements.org/vocab/InC/1.0/'}],
#   'http://www.openarchives.org/ore/terms/aggregates': [{'@id': '_:b2'},
#    {'@id': '_:b0'},
#    {'@id': '_:b1'}]},
#  {'@id': '_:b2',
#   '@type': ['http://schemas.delving.eu/nave/terms/DcnResource'],
#   'http://schemas.delving.eu/nave/terms/material': [{'@value': 'papier'},
#    {'@value': 'barietpapier'}],
#   'http://schemas.delving.eu/nave/terms/province': [{'@value': 'Noord-Holland'}],
#   'http://schemas.delving.eu/nave/terms/technique': [{'@value': 'gefotografeerd'}]},
#  {'@id': '_:b1',
#   '@type': ['http://schemas.delving.eu/nave/terms/DelvingResource'],
#   'http://schemas.delving.eu/nave/terms/allowDeepZoom': [{'@value': 'true'}],
#   'http://schemas.delving.eu/nave/terms/allowLinkedOpenData': [{'@value': 'true'}],
#   'http://schemas.delving.eu/nave/terms/allowSourceDownload': [{'@value': 'false'}],
#   'http://schemas.delving.eu/nave/terms/featured': [{'@value': 'false'}],
#   'http://schemas.delving.eu/nave/terms/public': [{'@value': 'true'}]},
#  {'@id': '_:b0',
#   '@type': ['http://schemas.delving.eu/nave/terms/RijksCollection'],
#   'http://schemas.delving.eu/nave/terms/rijksCollection': [{'@value': 'true'}]}]
